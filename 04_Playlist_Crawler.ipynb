# %% [markdown]
# # Import Packages

# %%
import sys
import spotipy
import spotipy.util as util
import sqlite3
from spotipy.client import SpotifyException

import numpy as np

from collections import Counter
from gensim.utils import tokenize

import time
import json
import ndjson
import tqdm

import requests
from bs4 import BeautifulSoup

from creds import *

# %% [markdown]
# ## Get Data

# %% [markdown]
# Getting the initial 1 million playlists using a list of musical terms is useful to get started collecting songs. However, given that collected playlists can be deleted and new playlists are constantly being created, it is useful to continue collecting more playlists.
#
# The Crawler will ensure that the retrieved playlists are not duplicates that have already been collected, and will add that playlist to the collection.

# %%
# Re-run music terms to find new playlists
music_terms =   ["a",
                 "discography",
                 "collection",
                 "soundtrack",
                 "rock",
                 "hiphop",
                 "jazz",
                 "metal", 
                 "classical",
                 "pop",
                 "country",
                 "blues",
                 "rap",
                 "hits",
                 "top",
                 "workout",
                 "my",
                 "playlist",
                 "mood",
                 "hype",
                 "spotify",
                 "vibe",
                 "musical",
                 "recent",
                 "night",
                 "day",
                 "positive",
                 "all",
                 "dance",
                 "latin",
                 "southern",
                 "electropop",
                 "tropical",
                 "contemporary",
                 "alternative",
                 "gangster",
                 "soul",
                 "house",
                 "progressive",
                 "modern"
                ]

# %% [markdown]
# ## Define Get Playlists

# %%
def find_playlists(session, w, max_count=1950):
    try:
        res = session.search(w, limit=50, type='playlist')
        while res:
            for playlist in res['playlists']['items']:
                yield playlist
                max_count -= 1
                if max_count == 0:
                    return
            tries = 3
            while tries > 0:
                try:
                    res = session.next(res['playlists'])
                    tries = 0
                except SpotifyException as e:
                    tries -= 1
                    time.sleep(0.2)
                    if tries == 0:
                        raise
    except SpotifyException as e:
        status = e.http_status
        if status == 404:
            raise StopIteration
        raise

# %% [markdown]
# ## Define Get Tracks

# %%
def track_yielder(session, playlist):
    res = session.user_playlist_tracks(playlist['owner'], playlist['id'],
              fields = 'items(track(id, name, artists(name, id), duration_ms)),next')
    while res:
        for track in res['items']:
            if track['track']:
                yield track['track']
        tries = 3
        while tries > 0:
            try:
                res = session.next(res)
                if not res or not res.get('items'):
                    return
                tries = 0
            except SpotifyException as e:
                if 400 <= e.http_status <= 499:
                    raise StopIteration
                tries -= 1
                time.sleep(1)
                if tries == 0:
                    raise e

# %% [markdown]
# ## Get New Playlists from Search Terms

# %%
# Load Playlist object with current playlists
playlists = json.load(open("data/playlists.json"))

# Create set of seen terms and counters
words_seen = set()
new_playlists = {}
count = 0
dupes = 0

# %%
for term in music_terms:
    # Set the counter for the search term
    count_term = 0
    
    # Set the Counter for popular terms and only proceed with unique search terms
    if not term in words_seen:
        word_counts = Counter({term : 1})
    
        # Get 10,000 playlists for each unique term
        while count_term < 10000:
            for word, _ in word_counts.most_common():
                if not word in words_seen:
                    words_seen.add(word)
                    print(f"Total playlist count is {count}...")
                    print(f"Term playlist count is {count_term}...")
                    print('word>', word)
                    print("")
                    for playlist in find_playlists(session, word):
                        if playlist['id'] in playlists: 
                            dupes += 1
                        elif playlist['name'] and playlist['owner']: 
                            new_playlists[playlist['id']] = {
                                  'owner': playlist['owner']['id'],
                                  'name': playlist['name'],
                                  'id': playlist['id'],
                            }
                            count += 1
                            count_term += 1
                            for token in tokenize(playlist['name'], lowercase=True): 
                                word_counts[token] += 1
                    break
    else:
        print("Repeated Term")
        print("")
# Out:
# Total playlist count is 0...
# Term playlist count is 0...
# word> a
#
# Total playlist count is 897...
# Term playlist count is 897...
# word> songs
#
# Total playlist count is 1819...
# Term playlist count is 1819...
# word> all
#
# Total playlist count is 2780...
# Term playlist count is 2780...
# word> alle
#
# Total playlist count is 4226...
# Term playlist count is 4226...
# word> hörspiele
#
# Total playlist count is 6086...
# Term playlist count is 6086...
# word> die
#
# Total playlist count is 7432...
# Term playlist count is 7432...
# word> folgen
#
# Total playlist count is 8444...
# Term playlist count is 8444...
# word> drei
#
# Total playlist count is 9689...
# Term playlist count is 9689...
# word> und
#
# Total playlist count is 10410...
# Term playlist count is 0...
# word> discography
#
# Total playlist count is 11124...
# Term playlist count is 714...
# word> complete
#
# Total playlist count is 11603...
# Term playlist count is 1193...
# word> the
#
# Total playlist count is 12485...
# Term playlist count is 2075...
# word> collection
#
# Total playlist count is 13095...
# Term playlist count is 2685...
# word> of
#
# Total playlist count is 13788...
# Term playlist count is 3378...
# word> best
#
# Total playlist count is 14372...
# Term playlist count is 3962...
# word> playlist
#
# Total playlist count is 15378...
# Term playlist count is 4968...
# word> s
#
# Total playlist count is 16297...
# Term playlist count is 5887...
# word> official
#
# Total playlist count is 17318...
# Term playlist count is 6908...
# word> soundtrack
#
# Total playlist count is 17972...
# Term playlist count is 7562...
# word> music
#
# Total playlist count is 18718...
# Term playlist count is 8308...
# word> hits
#
# Total playlist count is 19332...
# Term playlist count is 8922...
# word> is
#
# Total playlist count is 19505...
# Term playlist count is 9095...
# word> this
#
# Total playlist count is 19667...
# Term playlist count is 9257...
# word> top
#
# Total playlist count is 20276...
# Term playlist count is 9866...
# word> soundtracks
#
# Repeated Term
#
# Repeated Term
#
# Total playlist count is 21480...
# Term playlist count is 0...
# word> rock
#
# Total playlist count is 22106...
# Term playlist count is 626...
# word> indie
#
# Total playlist count is 23036...
# Term playlist count is 1556...
# word> pop
#
# Total playlist count is 23776...
# Term playlist count is 2296...
# word> folk
#
# Total playlist count is 24545...
# Term playlist count is 3065...
# word> folklore
#
# Total playlist count is 26428...
# Term playlist count is 4948...
# word> vibes
#
# Total playlist count is 27678...
# Term playlist count is 6198...
# word> chill
#
# Total playlist count is 28551...
# Term playlist count is 7071...
# word> lofi
#
# Total playlist count is 29674...
# Term playlist count is 8194...
# word> beats
#
# Total playlist count is 30560...
# Term playlist count is 9080...
# word> to
#
# Total playlist count is 31576...
# Term playlist count is 0...
# word> hiphop
#
# Total playlist count is 32426...
# Term playlist count is 850...
# word> rap
#
# Total playlist count is 33326...
# Term playlist count is 1750...
# word> hop
#
# Total playlist count is 34003...
# Term playlist count is 2427...
# word> hip
#
# Total playlist count is 34687...
# Term playlist count is 3111...
# word> b
#
# Total playlist count is 35623...
# Term playlist count is 4047...
# word> r
#
# Total playlist count is 36510...
# Term playlist count is 4934...
# word> trap
#
# Total playlist count is 37436...
# Term playlist count is 5860...
# word> workout
#
# Total playlist count is 38176...
# Term playlist count is 6600...
# word> mix
#
# Total playlist count is 38899...
# Term playlist count is 7323...
# word> bass
#
# Total playlist count is 39672...
# Term playlist count is 8096...
# word> house
#
# Total playlist count is 40376...
# Term playlist count is 8800...
# word> deep
#
# Total playlist count is 41077...
# Term playlist count is 9501...
# word> and
#
# Total playlist count is 41842...
# Term playlist count is 0...
# word> jazz
#
# Total playlist count is 42348...
# Term playlist count is 506...
# word> jazzy
#
# Total playlist count is 43957...
# Term playlist count is 2115...
# word> lounge
#
# Total playlist count is 45093...
# Term playlist count is 3251...
# word> chillout
#
# Total playlist count is 46556...
# Term playlist count is 4714...
# word> relax
#
# Total playlist count is 47576...
# Term playlist count is 5734...
# word> relaxing
#
# Total playlist count is 48598...
# Term playlist count is 6756...
# word> for
#
# Total playlist count is 49526...
# Term playlist count is 7684...
# word> study
#
# Total playlist count is 50513...
# Term playlist count is 8671...
# word> sleep
#
# Total playlist count is 51351...
# Term playlist count is 9509...
# word> piano
#
# Total playlist count is 51950...
# Term playlist count is 0...
# word> metal
#
# Total playlist count is 52555...
# Term playlist count is 605...
# word> metallica
#
# Total playlist count is 54319...
# Term playlist count is 2369...
# word> heavy
#
# Total playlist count is 55252...
# Term playlist count is 3302...
# word> metalcore
#
# Total playlist count is 57028...
# Term playlist count is 5078...
# word> hardcore
#
# Total playlist count is 57966...
# Term playlist count is 6016...
# word> post
#
# Total playlist count is 59017...
# Term playlist count is 7067...
# word> punk
#
# Total playlist count is 59753...
# Term playlist count is 7803...
# word> malone
#
# Total playlist count is 61256...
# Term playlist count is 9306...
# word> new
#
# Total playlist count is 62040...
# Term playlist count is 0...
# word> classical
#
# Total playlist count is 62659...
# Term playlist count is 619...
# word> guitar
#
# Total playlist count is 63372...
# Term playlist count is 1332...
# word> guitarra
#
# Total playlist count is 65141...
# Term playlist count is 3101...
# word> guitarras
#
# Total playlist count is 67053...
# Term playlist count is 5013...
# word> y
#
# Total playlist count is 67811...
# Term playlist count is 5771...
# word> de
#
# Total playlist count is 68556...
# Term playlist count is 6516...
# word> la
#
# Total playlist count is 69467...
# Term playlist count is 7427...
# word> en
#
# Total playlist count is 70263...
# Term playlist count is 8223...
# word> e
#
# Total playlist count is 71049...
# Term playlist count is 9009...
# word> el
#
# Total playlist count is 71945...
# Term playlist count is 9905...
# word> para
#
# Repeated Term
#
# Total playlist count is 72729...
# Term playlist count is 0...
# word> country
#
# Total playlist count is 73355...
# Term playlist count is 626...
# word> love
#
# Total playlist count is 74251...
# Term playlist count is 1522...
# word> in
#
# Total playlist count is 75077...
# Term playlist count is 2348...
# word> i
#
# Total playlist count is 75547...
# Term playlist count is 2818...
# word> you
#
# Total playlist count is 76646...
# Term playlist count is 3917...
# word> your
#
# Total playlist count is 77564...
# Term playlist count is 4835...
# word> re
#
# Total playlist count is 78566...
# Term playlist count is 5837...
# word> me
#
# Total playlist count is 79382...
# Term playlist count is 6653...
# word> with
#
# Total playlist count is 80517...
# Term playlist count is 7788...
# word> falling
#
# Total playlist count is 82309...
# Term playlist count is 9580...
# word> my
#
# Total playlist count is 83476...
# Term playlist count is 0...
# word> blues
#
# Total playlist count is 84095...
# Term playlist count is 619...
# word> soul
#
# Total playlist count is 84817...
# Term playlist count is 1341...
# word> soulful
#
# Total playlist count is 86540...
# Term playlist count is 3064...
# word> soulfull
#
# Total playlist count is 88045...
# Term playlist count is 4569...
# word> soulfully
#
# Total playlist count is 88277...
# Term playlist count is 4801...
# word> funky
#
# Total playlist count is 89725...
# Term playlist count is 6249...
# word> funk
#
# Total playlist count is 90569...
# Term playlist count is 7093...
# word> disco
#
# Total playlist count is 91259...
# Term playlist count is 7783...
# word> tunes
#
# Total playlist count is 92135...
# Term playlist count is 8659...
# word> fresh
#
# Repeated Term
#
# Repeated Term
#
# Repeated Term
#
# Repeated Term
#
# Repeated Term
#
# Repeated Term
#
# Total playlist count is 93544...
# Term playlist count is 0...
# word> mood
#
# Total playlist count is 94737...
# Term playlist count is 1193...
# word> good
#
# Total playlist count is 95706...
# Term playlist count is 2162...
# word> feel
#
# Total playlist count is 96908...
# Term playlist count is 3364...
# word> feels
#
# Total playlist count is 98528...
# Term playlist count is 4984...
# word> feeling
#
# Total playlist count is 100008...
# Term playlist count is 6464...
# word> feelings
#
# Total playlist count is 101773...
# Term playlist count is 8229...
# word> like
# Total playlist count is 102816...
# Term playlist count is 9272...
# word> that
#
# Total playlist count is 103893...
# Term playlist count is 0...
# word> hype
#
# Total playlist count is 105160...
# Term playlist count is 1267...
# word> up
#
# Total playlist count is 106007...
# Term playlist count is 2114...
# word> upbeat
#
# Total playlist count is 107394...
# Term playlist count is 3501...
# word> happy
#
# Total playlist count is 108626...
# Term playlist count is 4733...
# word> updated
#
# Total playlist count is 109474...
# Term playlist count is 5581...
# word> weekly
#
# Total playlist count is 110408...
# Term playlist count is 6515...
# word> dance
#
# Total playlist count is 111126...
# Term playlist count is 7233...
# word> party
#
# Total playlist count is 111891...
# Term playlist count is 7998...
# word> edm
#
# Total playlist count is 112724...
# Term playlist count is 8831...
# word> summer
#
# Total playlist count is 113961...
# Term playlist count is 0...
# word> spotify
#
# Total playlist count is 114562...
# Term playlist count is 601...
# word> on
#
# Total playlist count is 115588...
# Term playlist count is 1627...
# word> only
#
# Total playlist count is 116811...
# Term playlist count is 2850...
# word> bangers
#
# Total playlist count is 117968...
# Term playlist count is 4007...
# word> d
#
# Total playlist count is 118881...
# Term playlist count is 4920...
# word> one
#
# Total playlist count is 119680...
# Term playlist count is 5719...
# word> when
#
# Total playlist count is 120941...
# Term playlist count is 6980...
# word> it
#
# Total playlist count is 122044...
# Term playlist count is 8083...
# word> italia
#
# Total playlist count is 123439...
# Term playlist count is 9478...
# word> italian
#
# Total playlist count is 124905...
# Term playlist count is 0...
# word> vibe
#
# Total playlist count is 126196...
# Term playlist count is 1291...
# word> vibez
#
# Total playlist count is 128068...
# Term playlist count is 3163...
# word> vibezz
#
# Total playlist count is 130000...
# Term playlist count is 5095...
# word> vibezzz
#
# Total playlist count is 131938...
# Term playlist count is 7033...
# word> vibezzzz
#
# Total playlist count is 133883...
# Term playlist count is 8978...
# word> vibezzzzz
#
# Total playlist count is 135830...
# Term playlist count is 0...
# word> musical
#
# Total playlist count is 136794...
# Term playlist count is 964...
# word> musicals
#
# Total playlist count is 138677...
# Term playlist count is 2847...
# word> broadway
#
# Total playlist count is 140496...
# Term playlist count is 4666...
# word> disney
#
# Total playlist count is 141808...
# Term playlist count is 5978...
# word> bops
#
# Total playlist count is 143538...
# Term playlist count is 7708...
# word> baby
#
# Total playlist count is 144851...
# Term playlist count is 9021...
# word> lil
#
# Total playlist count is 146287...
# Term playlist count is 0...
# word> recent
#
# Total playlist count is 147515...
# Term playlist count is 1228...
# word> recents
#
# Total playlist count is 149446...
# Term playlist count is 3159...
# word> recently
#
# Total playlist count is 150681...
# Term playlist count is 4394...
# word> added
#
# Total playlist count is 151582...
# Term playlist count is 5295...
# word> récents
#
# Total playlist count is 153513...
# Term playlist count is 7226...
# word> played
#
# Total playlist count is 154501...
# Term playlist count is 8214...
# word> most
#
# Total playlist count is 155225...
# Term playlist count is 8938...
# word> mostly
#
# Total playlist count is 156746...
# Term playlist count is 0...
# word> night
#
# Total playlist count is 157748...
# Term playlist count is 1002...
# word> nights
#
# Total playlist count is 159361...
# Term playlist count is 2615...
# word> late
#
# Total playlist count is 160290...
# Term playlist count is 3544...
# word> latest
#
# Total playlist count is 161356...
# Term playlist count is 4610...
# word> at
#
# Total playlist count is 162566...
# Term playlist count is 5820...
# word> sad
#
# Total playlist count is 163654...
# Term playlist count is 6908...
# word> drives
#
# Total playlist count is 165507...
# Term playlist count is 8761...
# word> long
#
# Total playlist count is 166875...
# Term playlist count is 0...
# word> day
#
# Total playlist count is 167880...
# Term playlist count is 1005...
# word> days
#
# Total playlist count is 169316...
# Term playlist count is 2441...
# word> rainy
#
# Total playlist count is 171029...
# Term playlist count is 4154...
# word> autumn
#
# Total playlist count is 172854...
# Term playlist count is 5979...
# word> fall
#
# Total playlist count is 174301...
# Term playlist count is 7426...
# word> cozy
#
# Total playlist count is 176110...
# Term playlist count is 9235...
# word> morning
#
# Total playlist count is 177303...
# Term playlist count is 0...
# word> positive
#
# Total playlist count is 178771...
# Term playlist count is 1468...
# word> energy
#
# Total playlist count is 180102...
# Term playlist count is 2799...
# word> bitch
#
# Total playlist count is 181473...
# Term playlist count is 4170...
# word> bad
#
# Total playlist count is 182630...
# Term playlist count is 5327...
# word> bunny
#
# Total playlist count is 183948...
# Term playlist count is 6645...
# word> bitches
#
# Total playlist count is 185762...
# Term playlist count is 8459...
# word> fuck
#
# Total playlist count is 186966...
# Term playlist count is 9663...
# word> fucking
#
# Repeated Term
#
# Repeated Term
#
# Total playlist count is 188676...
# Term playlist count is 0...
# word> latin
#
# Total playlist count is 189625...
# Term playlist count is 949...
# word> latino
#
# Total playlist count is 190759...
# Term playlist count is 2083...
# word> latinos
#
# Total playlist count is 192538...
# Term playlist count is 3862...
# word> reggaeton
#
# Total playlist count is 193347...
# Term playlist count is 4671...
# word> los
#
# Total playlist count is 193940...
# Term playlist count is 5264...
# word> español
#
# Total playlist count is 194839...
# Term playlist count is 6163...
# word> exitos
#
# Total playlist count is 196063...
# Term playlist count is 7387...
# word> éxitos
#
# Total playlist count is 197290...
# Term playlist count is 8614...
# word> grandes
#
# Total playlist count is 198523...
# Term playlist count is 9847...
# word> del
#
# Total playlist count is 199237...
# Term playlist count is 0...
# word> southern
#
# Total playlist count is 200534...
# Term playlist count is 1297...
# word> gospel
#
# Total playlist count is 201330...
# Term playlist count is 2093...
# word> comfort
#
# Total playlist count is 203027...
# Term playlist count is 3790...
# word> zone
#
# Total playlist count is 204488...
# Term playlist count is 5251...
# word> comfortable
#
# Total playlist count is 206411...
# Term playlist count is 7174...
# word> out
#
# Total playlist count is 207272...
# Term playlist count is 8035...
# word> silence
#
# Total playlist count is 209163...
# Term playlist count is 9926...
# word> sound
#
# Total playlist count is 209915...
# Term playlist count is 0...
# word> electropop
#
# Total playlist count is 211254...
# Term playlist count is 1339...
# word> synth
#
# Total playlist count is 212681...
# Term playlist count is 2766...
# word> synthwave
#
# Total playlist count is 214366...
# Term playlist count is 4451...
# word> retrowave
#
# Total playlist count is 216207...
# Term playlist count is 6292...
# word> outrun
#
# Total playlist count is 218092...
# Term playlist count is 8177...
# word> cyberpunk
#
# Total playlist count is 219932...
# Term playlist count is 0...
# word> tropical
#
# Total playlist count is 220918...
# Term playlist count is 986...
# word> tropicales
#
# Total playlist count is 222837...
# Term playlist count is 2905...
# word> cumbias
#
# Total playlist count is 224178...
# Term playlist count is 4246...
# word> viejitas
#
# Total playlist count is 225840...
# Term playlist count is 5908...
# word> pero
#
# Total playlist count is 227428...
# Term playlist count is 7496...
# word> bonitas
#
# Total playlist count is 229275...
# Term playlist count is 9343...
# word> canciones
# HTTP Error for GET to https://api.spotify.com/v1/search?query=canciones&type=playlist&offset=2000&limit=50 returned 404 due to Not found.
# HTTP Error for GET to https://api.spotify.com/v1/search?query=canciones&type=playlist&offset=2000&limit=50 returned 404 due to Not found.
# HTTP Error for GET to https://api.spotify.com/v1/search?query=canciones&type=playlist&offset=2000&limit=50 returned 404 due to Not found.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     243
# --> 244             response.raise_for_status()
#     245             results = response.json()
#
# ~/anaconda3/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/search?query=canciones&type=playlist&offset=2000&limit=50
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-3-71fd49758f40> in find_playlists(session, w, max_count)
#      12                 try:
# ---> 13                     res = session.next(res['playlists'])
#      14                     tries = 0
#
# ~/anaconda3/lib/python3.8/site-packages/spotipy/client.py in next(self, result)
#     307         if result["next"]:
# --> 308             return self._get(result["next"])
#     309         else:
#
# ~/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     283
# --> 284         return self._internal_call("GET", url, payload, kwargs)
#     285
#
# ~/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     258
# --> 259             raise SpotifyException(
#     260                 response.status_code,
#
# SpotifyException: http status: 404, code:-1 - https://api.spotify.com/v1/search?query=canciones&type=playlist&offset=2000&limit=50:
#  Not found., reason: None
#
# During handling of the above exception, another exception occurred:
#
# StopIteration                             Traceback (most recent call last)
# <ipython-input-3-71fd49758f40> in find_playlists(session, w, max_count)
#      22         if status == 404:
# ---> 23             raise StopIteration
#      24         raise
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-2283ef8f827e> in <module>
#      16                     print('word>', word)
#      17                     print("")
# ---> 18                     for playlist in find_playlists(session, word):
#      19                         if playlist['id'] in playlists:
#      20                             dupes += 1
#
# RuntimeError: generator raised StopIteration

# %% [markdown]
# ## Get Tracks for New Playlists

# %%
# Get collected tracks
conn = sqlite3.connect('data/songs.db')
c = conn.cursor()
c.execute("SELECT id FROM songs")

sql_tracks = c.fetchall()

# %%
# Clean tuple format from SQL response
tracks_seen = set()
for i in range(len(sql_tracks)):
    tracks_seen.add(sql_tracks[i][0])

# %%
len(new_playlists.keys())
# Out:
# 167021

# %%
# Retrieve new tracks and save them
count = 0
with open('data/playlists.ndjson', 'a') as fout_playlists:
    with open('data/songs_ids.txt', 'a') as fout_song_ids:
        for playlist in tqdm.tqdm_notebook(new_playlists.values()):
            try:
                fout_playlists.write(json.dumps(playlist) + '\n')
                track_ids = []
                for track in track_yielder(session, playlist):
                    track_id = track['id']
                    if not track_id:
                        continue
                    if not track_id in tracks_seen:
                        c.execute("INSERT INTO songs VALUES (?, ?, ?)", 
                                  (track['id'], track['name'], track['artists'][0]['name']))
                    track_ids.append(track_id)
                    tracks_seen.add(track_id)
                fout_song_ids.write(' '.join(track_ids) + '\n')
                conn.commit()
            except:
                session = spotipy.Spotify(auth_manager = spotipy.SpotifyOAuth(
                    client_id = client_id,
                    client_secret = client_secret,
                    scope = scope,
                    username = user_id,
                    redirect_uri = redirect_uri
                ))
                count += 1
                print(f"Playlist Failures: {count}")
                print(playlist)
conn.commit()
# Out:
# <ipython-input-15-5a3ab834cee6>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for playlist in tqdm.tqdm_notebook(new_playlists.values()):
# HBox(children=(FloatProgress(value=0.0, max=167021.0), HTML(value='')))
# Playlist Failures: 1
# {'owner': 'tsn2h1b8vlso76s57r18ypbgy', 'name': 'Bad Day Songs', 'id': '39dsya7LXa138jJQ3SxCXT'}
# Playlist Failures: 2
# {'owner': 'ibrahimazalan', 'name': 'MALAY JIWANG SONGSSS', 'id': '52xB8CslxfwjgxKuoqkZUD'}
# Playlist Failures: 3
# {'owner': 'phillcrap', 'name': 'UFC entrance songs', 'id': '3ZBsmwzFkOiLEKHmp5GUIr'}
# Playlist Failures: 4
# {'owner': '31f6abr4mxtewvs5tcwqle53fbx4', 'name': 'Mizo Songs', 'id': '4Cgr2TjeSxWgv51kU5xciC'}
# Playlist Failures: 5
# {'owner': 'manelijamal', 'name': 'Reading Music (Focus, Concentration, Study)', 'id': '6tpnEvjXNhjYm1nXDVfCnB'}
# Playlist Failures: 6
# {'owner': '11181340712', 'name': 'Piano & Violin & Cello', 'id': '3XAqOmvG9TI0FEu59wgbkX'}
# Playlist Failures: 7
# {'owner': 'ninaxlice', 'name': 'ROCK/ METAL', 'id': '6dGI96SVg4FkI6txjIUOgT'}
# Max Retries reached
# Playlist Failures: 8
# {'owner': 'kevin.engevik', 'name': 'Vibezzz', 'id': '5OE2k55TLljq6Ao4HZcr39'}
# Playlist Failures: 9
# {'owner': 'andybiersackismyhusband', 'name': 'underrated bops', 'id': '5pevnYh1W40Kl3enmVdx8p'}
# Playlist Failures: 10
# {'owner': 'annamahrt', 'name': 'well played', 'id': '52kTlgLYj9GOKFF90GbbBW'}
# Playlist Failures: 11
# {'owner': 'jlaroa69', 'name': 'Nightshift', 'id': '7khg1KoQh2axzxeGB4VPte'}
# Playlist Failures: 12
# {'owner': 'ewanney', 'name': 'nights like these', 'id': '286al9xj4atDSimvIZnfPU'}
# Playlist Failures: 13
# {'owner': '22rcgzjaspkgzhkpive7twziq', 'name': 'Naija 2019 latest', 'id': '4lP9dg7CTZEDubRObKimB8'}
# Playlist Failures: 14
# {'owner': '763fj5pu4ep7lqnjxgl9px1pt', 'name': 'Trap Town Records', 'id': '4nag0wtET3KIKRrj7wJQ2y'}
# Playlist Failures: 15
# {'owner': 'chingoncito', 'name': 'Latest Salsa Jams', 'id': '1XrWlxzw1uRX9qa2nWkQtm'}
# Playlist Failures: 16
# {'owner': '11766014', 'name': 'PTV, SWS, ATL, P!ATD, MCR, ADTR, BMTH, FIR, PVRIS, PARAMORE, TA, YMAS, TWL, AS IT IS, ANDY BLACK', 'id': '0xSwV4OJqfPCdYkvAz3egU'}
# Playlist Failures: 17
# {'owner': 'ukswpiz2uuypyrp1ddzkf9kyw', 'name': 'ÜLKÜCÜ FLÖRTE ATMALIK ', 'id': '3qNiN866mIL26eiDCOKL0q'}
# Playlist Failures: 18
# {'owner': '1266750003', 'name': 'Drives', 'id': '1BK5DtXdIkc6QOWC21nIlG'}
# Playlist Failures: 19
# {'owner': 'kmchughkerr', 'name': 'Chill Drives', 'id': '5kFbMung4hvMsGTHwyGZFI'}
# Playlist Failures: 20
# {'owner': '1290690906', 'name': 'Long Trip Playlist', 'id': '5rPSbaxX51mHPfFf8LAis1'}
# Playlist Failures: 21
# {'owner': '117992214', 'name': 'Puttre i longsen', 'id': '4mIEn2ICXIyCiOUHcUcTaI'}
# Playlist Failures: 22
# {'owner': '0du00r2qmsk9xqtoxn8sqnt9s', 'name': 'Long Tall Sally ( RIP) ', 'id': '3YT6SroiQGevGHmIjnnvwM'}
# Playlist Failures: 23
# {'owner': 'da_panda_man', 'name': 'long c', 'id': '3on4j9gA1E11w4DcYQbhYj'}
# Playlist Failures: 24
# {'owner': 'vzxefmug09np6e5axp80nj40j', 'name': 'longhe longhe.', 'id': '4RQSe9wYG4DXhLKZs5bBIr'}
# Playlist Failures: 25
# {'owner': 'sonymusicnz', 'name': 'Weekend Roadtrip', 'id': '1TVTc9vBgTx6nNkLsaqnrk'}
# Playlist Failures: 26
# {'owner': 'donovannxxx', 'name': 'chin chong ling long', 'id': '6AtvzeHduTchURCYpAdUUo'}
# Playlist Failures: 27
# {'owner': '7qtlrdlbas5zm7uri064iy0ga', 'name': 'daydreaming 🌊☁️✨', 'id': '4n8kXKjapFtP6kuCjEgGIg'}
# Playlist Failures: 28
# {'owner': '22nlnrexfyokv6vjiiqxdi5oi', 'name': 'feel good days', 'id': '4WpUULci23n8gSwpHf6Q6I'}
# Playlist Failures: 29
# {'owner': 'cbagal', 'name': 'Lake Days ⚓️', 'id': '48rvBYe3CNRNMYgZq3CTpL'}
# Playlist Failures: 30
# {'owner': 'avillanuj1233488', 'name': 'WFM 96.9, Radioactivo 98.5 & Rock 101', 'id': '7qBhap0tLm9LksIenEvzE5'}
# Playlist Failures: 31
# {'owner': 'joshryanolivier-us', 'name': 'Calm Coffee Morning Bedtime🍁🌻🌾', 'id': '183gI6maUoj3vi1WGDWq02'}
# Playlist Failures: 32
# {'owner': 'angelical1102', 'name': 'Rainy Day ', 'id': '3QGlDSXEDDFm17YDUhxqQI'}
# Playlist Failures: 33
# {'owner': '1228444392', 'name': 'Rainy Day', 'id': '5lBUAIg70kK7cy9kbdMQuU'}
# Playlist Failures: 34
# {'owner': 'marcecol2016', 'name': 'Rainyxstar', 'id': '1F7B7b05bm7AmZkmgr1AT9'}
# Playlist Failures: 35
# {'owner': 'gpize8zc67kon2b2jkpwl7hr8', 'name': 'rainycore', 'id': '1SUHZ6doplEaiTFQLMIrUA'}
# Playlist Failures: 36
# {'owner': '8oxlxr96okcg9j1e8uxb7ivst', 'name': 'rainy morning vibes', 'id': '68JXXhoryZx5e3sQNTJ6gI'}
# Playlist Failures: 37
# {'owner': 'jdt8yp5hjir5sraplmtg1lezk', 'name': 'Romantic Rainy Mood', 'id': '4iApfELpbP3tVfudJrbIY5'}
# Playlist Failures: 38
# {'owner': 'littlejohnnyy', 'name': 'rainy day', 'id': '3UVphoJNOvPupYxCPDyLWX'}
# Playlist Failures: 39
# {'owner': '12161236204', 'name': 'Rainy OPM', 'id': '18ZSqzDPl4NUAgKrsq2LXm'}
# Playlist Failures: 40
# {'owner': '8vgoi9mms5wh4wxlvsnsgqbxv', 'name': 'rainy day', 'id': '2zD2vo6pVj0ztZVQzPJLCW'}
# Playlist Failures: 41
# {'owner': 'jana.erthel', 'name': 'rainy autumn days ', 'id': '0xejLekrzAxA9uuvhfjEPX'}
# Playlist Failures: 42
# {'owner': '1221442624', 'name': 'rainy day bop ✰', 'id': '1nCHSELT21noIYd9uloz10'}
# Playlist Failures: 43
# {'owner': 'mv8kop5yoyj8uo3k1omprku4a', 'name': 'Rainy days🌧️🎵', 'id': '4b6xDwGF4Ig81thRjPnQmQ'}
# Playlist Failures: 44
# {'owner': 'vxkbz2tpwmsxlnjyxsnmxrtq8', 'name': 'Rainy Days', 'id': '5j0f2smid9Z5E86BvmHjSf'}
# Playlist Failures: 45
# {'owner': '1220124484', 'name': 'rainy electronic ~vibes~', 'id': '4iePmK8blKvyizHzOmPU5l'}
# Playlist Failures: 46
# {'owner': '1283554236', 'name': 'rainy days bad weather', 'id': '2dfmxJaF4nWNopCj4Myadb'}
# Playlist Failures: 47
# {'owner': 'jose.cuerrvo45', 'name': 'Rainy Window Blues', 'id': '7iTyTj8FkvODgU0edw0zoE'}
# Playlist Failures: 48
# {'owner': 'emmymcl', 'name': 'rainy days 🌧', 'id': '3DX0MKWvvAXu91NAuOs7PW'}
# Playlist Failures: 49
# {'owner': 'bevb5b3ixpjvwoz2xznykuwfd', 'name': 'Rainy Days🌧', 'id': '5w4KoZF6bhiPGjr2t7pw0e'}
# Playlist Failures: 50
# {'owner': 'pocketer', 'name': 'rainy day', 'id': '4SwYbS109185wsNuHUh1Qh'}
# Playlist Failures: 51
# {'owner': 'alejandrodezag', 'name': 'AUTUMN_2020', 'id': '3ksRbp8GbP2lwElffvB7aS'}
# Playlist Failures: 52
# {'owner': '226eqdqcyddezjohbi3oyasoa', 'name': 'yoga early autumn ', 'id': '19feZdvV68ahb8kvLl7Nvt'}
# Playlist Failures: 53
# {'owner': '22ki2ksshrqlel25mw3bwfn7q', 'name': 'Autumns Faves 🔥🔥🔥', 'id': '71Im5XiL1b260uXjFJOTfO'}
# Playlist Failures: 54
# {'owner': '5aklz0zhmvyy8csv62jhh1pe9', 'name': 'Autumn Berlied ', 'id': '4QzmjMsxevPTsvrdHwfFLs'}
# Playlist Failures: 55
# {'owner': '31vzsiy56d4llcechsnjovhls6im', 'name': 'Autumn 🍂 ', 'id': '2VByyoe8r8ZdwFMTZEKGpV'}
# Playlist Failures: 56
# {'owner': 'screav', 'name': 'Autumn', 'id': '5cIqHkSIAaGfl6XfmnKYr2'}
# Playlist Failures: 57
# {'owner': '0cu7q1o4qq44c1dfn7xq33391', 'name': 'Gravity Falls Songs', 'id': '0JvMRPruc0kWo1DewQp8tB'}
# Playlist Failures: 58
# {'owner': 'jwalters016', 'name': 'fall vibes🍁', 'id': '20XL4Ik7e5SxFYYSQWxUxL'}
# Playlist Failures: 59
# {'owner': 'qt2000', 'name': 'cozy tapez 6', 'id': '3EHSyfUAh2JK50Lk7BN6Q0'}
# Playlist Failures: 60
# {'owner': 'ef.e23', 'name': 'That cozy shit ', 'id': '50A0vXRTgsJnRfL7eLT3Ru'}
# Playlist Failures: 61
# {'owner': 'jjayrod24', 'name': 'cozy', 'id': '3SZtCjXtZ8St1g6z0Y6HMv'}
# Playlist Failures: 62
# {'owner': 'jhs808e05t4h1k393gfhff559', 'name': 'cozy autumn days🍂☄️', 'id': '1XHrU5wAu7Zf0s5rQdUxwn'}
# Playlist Failures: 63
# {'owner': '313hvkf2ojlhftnlrxi2uoby3oye', 'name': 'cozy', 'id': '5IXiad0btXmguaC1N5Y2tM'}
# Playlist Failures: 64
# {'owner': 'e6jc0zaakxeluksw00scd2bx2', 'name': 'Cozy Fall Mix 🍁🎧🍁Mellow and Moving Tunes for Autumn. Quiet Mood. Deep Lyrics. Big Feels', 'id': '11fpUacMCf3YWxd1bOzgQZ'}
# Playlist Failures: 65
# {'owner': '45j5u87dwzf4bpmk02s7jxiyv', 'name': 'cozy bad', 'id': '6gQm7DH6QtNKRz8kFaUJzD'}
# Playlist Failures: 66
# {'owner': '21mlljpgfy7r3yrpqqrgbpmmy', 'name': 'Stay Cozy🚗 ', 'id': '6miy0eDbRm77orh7A4ydUp'}
# Playlist Failures: 67
# {'owner': 'neil_iii', 'name': '+ Best Workout Playlist (Positive)', 'id': '1vARlEsNaPpoZgdeB49p0l'}
# Playlist Failures: 68
# {'owner': 'ruhb9xltmbffye77o5epgohxc', 'name': 'positive vibes', 'id': '6DnUyD3XroiOKVgCAENSxn'}
# Playlist Failures: 69
# {'owner': '8sc6vd4uqtvirn0p5brqlf1w4', 'name': 'Positive Energy ', 'id': '6i8HdndryN0Ttn4HQp5pR3'}
# Max Retries reached
# Playlist Failures: 70
# {'owner': '11145391561', 'name': 'Positive vipes', 'id': '0T196BOScdv6aBRSdt3HU1'}
# Max Retries reached
# Playlist Failures: 71
# {'owner': 'broncosfan102134', 'name': 'Car- Positive rap', 'id': '2nQff1vRJ0u1SPD36k8Coy'}
# Playlist Failures: 72
# {'owner': 'tpf7li1ny1efmytmylm5kru85', 'name': 'Bakery Bitch Bangaz 🤘🏼', 'id': '0G2kpChKzAq1iFBz2zBLWm'}
# Playlist Failures: 73
# {'owner': 'keiraxquinn', 'name': 'sad bitch', 'id': '6Ie1y999UKgXd7IzV1WKcW'}
# Playlist Failures: 74
# {'owner': 'ruby_grace__', 'name': 'QUEEN SHIT ', 'id': '3UVanJ6YSWModhQ5pNmGIc'}
# Playlist Failures: 75
# {'owner': 'muk4jru1hy90ayehbqdn1t6vg', 'name': 'Stupid Like Bitch Fuck', 'id': '0tY2ZKWrcCkpzrMOH2N537'}
# Playlist Failures: 76
# {'owner': 'i3uvq32d09zi1xernmxyj45d9', 'name': 'i’m your bitch, you’re my bitch✨', 'id': '38sdMXo8imv98tOAML1mpv'}
# Playlist Failures: 77
# {'owner': '21c6b7szotlqr6u6p5zua45ni', 'name': 'Bad Bitches Playlist', 'id': '2UZnvJLPgWoOjlB2h3btVr'}
# Playlist Failures: 78
# {'owner': 'p9yk1yafz8c1ygqxmmkcn9obm', 'name': 'BAD BITCH (en español) ', 'id': '1wq9Boc3m7KymqCZJoGaLP'}
# Playlist Failures: 79
# {'owner': 'roosamaria.uosukainen', 'name': 'Later Bitches', 'id': '3IQMPyZJwGSfFr0TJ0BqPk'}
# Playlist Failures: 80
# {'owner': '1254620244', 'name': "bitchin'", 'id': '3hxNoYmcTzcqBhmIuzrkSC'}
# Playlist Failures: 81
# {'owner': 'ellamcphee98', 'name': 'It’s Britney Bitch', 'id': '58daG30U7rcCAV86cyJ4BP'}
# Playlist Failures: 82
# {'owner': 'brittanyjane3012', 'name': 'Bitch', 'id': '0IOGZIgyw9Fnxuk8fsZgwZ'}
# Playlist Failures: 83
# {'owner': '22samkay', 'name': 'bad bitch trap house ', 'id': '6kN5erjKIVSsM9F67JFLmS'}
# Playlist Failures: 84
# {'owner': '1zu3xoh0dgmota1yehliig5vz', 'name': 'bad bitch ', 'id': '6ibQYrgQ3Np5WUydMBfuOC'}
# Playlist Failures: 85
# {'owner': '22ksduewauxa5uw7neo3edm2a', 'name': 'THE BADDEST', 'id': '7KqZHmBgeLqPCgjAuNz9k0'}
# Playlist Failures: 86
# {'owner': 'hazeyhay', 'name': 'bitches n hoes', 'id': '1jF4NDkinzMol4XCo8Hi5J'}
# Playlist Failures: 87
# {'owner': 'jessi2106', 'name': 'dont let stupid bitches make u cry', 'id': '3Htasxwb1ceDkJ2ejrYReM'}
# Playlist Failures: 88
# {'owner': '12169912961', 'name': 'Lorella Bitches', 'id': '4ZE3PVcRxvRRmQKJTkRS4m'}
# Playlist Failures: 89
# {'owner': '1143417987', 'name': 'PALM TREES🌴 & BAD BITCHES👩🏾', 'id': '4zAXYzXQnV0Jty8Zq0yPNd'}
# Playlist Failures: 90
# {'owner': 'slinky2144', 'name': 'BITCHES & BANGERS', 'id': '6fAVsMEhPhg3CgUxsGN1Zn'}
# Playlist Failures: 91
# {'owner': 'x3azwiped6s9k0k2v9iqsptti', 'name': 'beyers bitches’', 'id': '4eCelxVDUCcRTPOac8zMAV'}
# Playlist Failures: 92
# {'owner': 'd6jj1xrnyfcsvupdjz5gtyptz', 'name': 'bad bitches', 'id': '2m34oyMOXWi2CstgecNNMr'}
# Playlist Failures: 93
# {'owner': '12159017132', 'name': 'grab a fucking beer ', 'id': '3TTPUHj8QplHkhOdsOJXT4'}
# Playlist Failures: 94
# {'owner': 'fernoubleau', 'name': 'Ritmo Latino 2020', 'id': '0bIACaNvov7vlaLJfpuqq7'}
# Playlist Failures: 95
# {'owner': 'fohae2me682f5yrz6v7lb73s6', 'name': 'Reggaeton del bueno 🔥', 'id': '1ovAS1sEJ1dXWxOoZ6RGOh'}
# Playlist Failures: 96
# {'owner': '12133350361', 'name': 'Reggaeton Noviembre 2020', 'id': '2n0qxrd6vbd4rGBm6KcCgY'}
# Playlist Failures: 97
# {'owner': '12155713120', 'name': 'REGGAETON // TRAP', 'id': '5EN8YagwyNxNDDQ864ZchA'}
# Playlist Failures: 98
# {'owner': '1256170015', 'name': 'Southern Comfort', 'id': '6ac1mYEjnmMQjnru0HvKka'}
# Playlist Failures: 99
# {'owner': 'dorchakl', 'name': 'Southern Side', 'id': '0a6tgdbQvLZgr1msj63dqR'}
# Playlist Failures: 100
# {'owner': 'gymgirl10255', 'name': 'southern belle', 'id': '0NCPYkQqcyO4MH6O0XHDnv'}
# Playlist Failures: 101
# {'owner': '12131257329', 'name': 'Southern gospel', 'id': '6n0CCXzuRTsYrTSfp75cnD'}
# Playlist Failures: 102
# {'owner': 'dcratt2376', 'name': 'Southern Gospel', 'id': '60NzLX1s50N4jHY23GYUzQ'}
# Playlist Failures: 103
# {'owner': 'rclancy38', 'name': 'Southern 🍗🍉', 'id': '2y7kvJ1ohMspr3pfMziAYg'}
# Playlist Failures: 104
# {'owner': 'calscustomkicks', 'name': 'Southern Sound', 'id': '4Vcnk3UaJqGMZTo7hFlUGE'}
# Playlist Failures: 105
# {'owner': 'evegeve4', 'name': 'indie comfort', 'id': '08El6FcWl2RVDhYDrRYdjV'}
# Playlist Failures: 106
# {'owner': 'maou69007', 'name': 'La zoneee', 'id': '432bf15uFyUXFsLrCVmpNP'}
# Playlist Failures: 107
# {'owner': 'nitoleogg', 'name': 'Zoned out', 'id': '4yvWyi7fJJ7hulvBw2HIg8'}
# Playlist Failures: 108
# {'owner': '5262matt', 'name': 'In the ZONE', 'id': '5fTTQAMgTZEIRUWuJmZ8sT'}
# Playlist Failures: 109
# {'owner': 'hil814tdtlwist1jcnjr82uah', 'name': 'Chill zone🦋', 'id': '39HBUizDPOItrBnf8HSfLd'}
# Playlist Failures: 110
# {'owner': '21rtskaa5ztlz72v3u2njltba', 'name': 'La zone', 'id': '27YhQ07I1YPE5OFoz6tLrq'}
# Playlist Failures: 111
# {'owner': '22ijojfmcouf7sr7kibr5jhoa', 'name': 'Too Comfortable', 'id': '39OuiDXsSC5OnF2Uiip8h0'}
# Playlist Failures: 112
# {'owner': '124713983', 'name': 'Comfortable - EP Version', 'id': '0VqctcYycYXPQTTSKMY0eG'}
# Playlist Failures: 113
# {'owner': '1222442199', 'name': 'I’m a little too comfortable with going to hell', 'id': '7Hnd3x3rC3fX8378ExZTo7'}
# Playlist Failures: 114
# {'owner': '22bmaowivqehq4fl3e7vzpzea', 'name': 'alt3rnative', 'id': '2kFfXr4pro7aQpMsBvVwjm'}
# Playlist Failures: 115
# {'owner': 'michael5035', 'name': '1 Charming warm  comfortable Music', 'id': '7vn6JBVkVaF4TvShMkZUyC'}
# Playlist Failures: 116
# {'owner': 'utp41444iy2r3mmbq2c92ezgc', 'name': 'Comfortable', 'id': '4MpopQBct7dLAtPnDVzG5W'}
# Playlist Failures: 117
# {'owner': 'robyrdh', 'name': 'Comfortable in Chaos', 'id': '2kviWxEsjWYvlH7G7aZNwe'}
# Playlist Failures: 118
# {'owner': 'famthorbjornsen', 'name': 'Jazz for the Good Night Drink', 'id': '3lHfRrQRqwF9F7XpmbQ3CQ'}
# Playlist Failures: 119
# {'owner': '31jaffxjlt6k7q77ypabspizr3vu', 'name': 'Indie, Electropop', 'id': '4nb69UYJT1n7MBAd6nJvZx'}
# Playlist Failures: 120
# {'owner': '21nf5gsqfxooywjgljzrpls3a', 'name': 'Electropop', 'id': '049mwyGxIi2J1zMxOjY6A0'}
# Playlist Failures: 121
# {'owner': 'kru5nlcu46xouhdgmwq6jzjhb', 'name': 'Indie \\ Electropop', 'id': '5HVtfYrnWYMFzSuEsi4r8V'}
# Playlist Failures: 122
# {'owner': 'kr9pvgz0nleu3anudku3ksz2y', 'name': 'Electropop', 'id': '47WwqlEqUOpAS4yJSFT4Cf'}
# Playlist Failures: 123
# {'owner': 'heytymon', 'name': 'Hyperpop; PC MUSIC; Electropop', 'id': '4OvYChE5Oc5H6SqhGzfpRe'}
# Playlist Failures: 124
# {'owner': 'k3y11p8axzg8n0mspog6xe4hf', 'name': 'ElectroPOP🎀', 'id': '5UKhpmxOjk7bWqbqqxsnP9'}
# Playlist Failures: 125
# {'owner': '1nwkjgjzhij0z9j9rexq11lf7', 'name': 'Electropop', 'id': '6ubsr9XzbXwVs4aGMsmSqd'}
# Playlist Failures: 126
# {'owner': 'danguzman.r', 'name': 'ElectroPop', 'id': '1RrOCux6lUKZ9JyvKGGFqP'}
# Playlist Failures: 127
# {'owner': '12146824185', 'name': 'Electropop', 'id': '74CWgv8EHQcAa5wyzHH3WV'}
# Playlist Failures: 128
# {'owner': '0adgla917l13hv4hy4kzk87us', 'name': 'ElectroPop', 'id': '7BKsiCqQz6bdknrU6FCA8f'}
# Playlist Failures: 129
# {'owner': 'euanmax-gb', 'name': 'Synthwave 80s Stuff', 'id': '346UDQY2OK4EGI9ccRfAbF'}
# Playlist Failures: 130
# {'owner': 'b2ebbbndvj1l3wxqfezjqrnhb', 'name': 'SYNTHWAVE', 'id': '4noGQfKLvh31qIeYzvAiFp'}
# Playlist Failures: 131
# {'owner': '1159089453', 'name': 'Retrowave', 'id': '5Dwsp2FjleAfC9EvI1pQFi'}
# Playlist Failures: 132
# {'owner': '1285970629', 'name': 'Retrowave', 'id': '5bxZxGCwuJND00CGRatTVy'}
# Playlist Failures: 133
# {'owner': 'davidagu323', 'name': 'Chill | Retrowave | Sythwave | Anime OST', 'id': '42xZm1vw7Z5xlGmLBpaH5r'}
# Playlist Failures: 134
# {'owner': 'baconboy3207', 'name': 'Racing RetroWave', 'id': '1dbBiAW5CEMAqkUuU9z1I1'}
# Playlist Failures: 135
# {'owner': '6egvkwp132ulzvft0qdly21s6', 'name': 'Chill/Tropical Rap', 'id': '2dOl2mLc4fRIPbHo1emHKH'}
# Playlist Failures: 136
# {'owner': 'varca14', 'name': 'tropicales', 'id': '7KGT8u8p8INJCUYlJ8CI1m'}
# Playlist Failures: 137
# {'owner': 'luzmarina_martinez', 'name': 'Tropicales Navidad', 'id': '2DCHVMUIxOtxeOC1vEACeN'}
# Playlist Failures: 138
# {'owner': '11157588916', 'name': 'Tropicales De Los 90`®', 'id': '4UGvKGd8MfkcSgua10qar5'}
# Playlist Failures: 139
# {'owner': 'maximinoperezaguilera', 'name': 'Tropicales del Sureste', 'id': '0TnPE8thgC8Iqc1cenfl6N'}
# Playlist Failures: 140
# {'owner': 'laurabonet7', 'name': 'Llámala x pero llámala', 'id': '2EOEZOCfeyU0jisc44mDjw'}
# Playlist Failures: 141
# {'owner': '12174230660', 'name': 'me gustan los aviones, me gustas tú', 'id': '631nGy3wGOslB8mKzM68sm'}
