# %% [markdown]
# # Import Packages

# %%
import sys
import spotipy
import spotipy.util as util
import sqlite3
from spotipy.client import SpotifyException

import numpy as np

from collections import Counter
from gensim.utils import tokenize

import time
import json
import ndjson
import tqdm

import requests
from bs4 import BeautifulSoup
from requests.exceptions import ReadTimeout

from creds import *

# %% [markdown]
# ## Get Data

# %% [markdown]
# Getting the initial 1 million playlists using a list of musical terms is useful to get started collecting songs. However, given that collected playlists can be deleted and new playlists are constantly being created, it is useful to continue collecting more playlists.
#
# The Crawler will ensure that the retrieved playlists are not duplicates that have already been collected, and will add that playlist to the collection.

# %%
# Re-run music terms to find new playlists
music_terms =   ["a",
                 "summer",
                 "discography",
                 "collection",
                 "soundtrack",
                 "rock",
                 "hiphop",
                 "jazz",
                 "metal", 
                 "classical",
                 "pop",
                 "country",
                 "blues",
                 "rap",
                 "hits",
                 "top",
                 "workout",
                 "my",
                 "playlist",
                 "mood",
                 "hype",
                 "spotify",
                 "vibe",
                 "musical",
                 "recent",
                 "night",
                 "day",
                 "positive",
                 "all",
                 "dance",
                 "latin",
                 "southern",
                 "electropop",
                 "tropical",
                 "contemporary",
                 "alternative",
                 "gangster",
                 "soul",
                 "house",
                 "progressive",
                 "modern"
                ]

# %% [markdown]
# ## Define Get Playlists

# %%
def find_playlists(session, w, max_count=750):
    try:
        res = session.search(w, limit=50, type='playlist')
        while res:
            for playlist in res['playlists']['items']:
                yield playlist
                max_count -= 1
                if max_count == 0:
                    return
            tries = 3
            while tries > 0:
                try:
                    res = session.next(res['playlists'])
                    tries = 0
                except SpotifyException as e:
                    tries -= 1
                    time.sleep(90)
                    if tries == 0:
                        raise
                
                except ReadTimeout:
                    print("Spotify timed out... Trying again...")
                    time.sleep(90)
                    
    except SpotifyException as e:
        status = e.http_status
        if status == 404:
            time.sleep(90)
            raise StopIteration
        raise

# %% [markdown]
# ## Define Get Tracks

# %%
def track_yielder(session, playlist):
    res = session.user_playlist_tracks(playlist['owner'], playlist['id'],
              fields = 'items(track(id, name, artists(name, id), duration_ms)),next')
    while res:
        for track in res['items']:
            if track['track']:
                yield track['track']
        tries = 3
        while tries > 0:
            try:
                res = session.next(res)
                if not res or not res.get('items'):
                    return
                tries = 0
            except SpotifyException as e:
                if 400 <= e.http_status <= 499:
                    raise StopIteration
                tries -= 1
                time.sleep(90)
                if tries == 0:
                    raise e

# %% [markdown]
# ## Get New Playlists from Search Terms

# %%
# Load Playlist object with current playlists
playlists = json.load(open("data/playlists.json"))

# Create set of seen terms and counters
words_seen = set()
new_playlists = {}
count = 0
dupes = 0

# %%
for term in music_terms:
    # Set the counter for the search term
    count_term = 0
    
    # Set the Counter for popular terms and only proceed with unique search terms
    if not term in words_seen:
        word_counts = Counter({term : 1})
    
        # Get 10,000 playlists for each unique term
        while count_term < 10000:
            for word, _ in word_counts.most_common():
                if not word in words_seen:
                    words_seen.add(word)
                    print(f"Total playlist count is {count}...")
                    print(f"Term playlist count is {count_term}...")
                    print('word>', word)
                    print("")
                    for playlist in find_playlists(session, word):
                        if playlist['id'] in playlists: 
                            dupes += 1
                        elif playlist['name'] and playlist['owner']: 
                            new_playlists[playlist['id']] = {
                                  'owner': playlist['owner']['id'],
                                  'name': playlist['name'],
                                  'id': playlist['id'],
                            }
                            count += 1
                            count_term += 1
                            for token in tokenize(playlist['name'], lowercase=True): 
                                word_counts[token] += 1
                    break
    else:
        print("Repeated Term")
        print("")
# Out:
# Total playlist count is 0...
# Term playlist count is 0...
# word> a
#
# Total playlist count is 436...
# Term playlist count is 436...
# word> y
#
# Total playlist count is 809...
# Term playlist count is 809...
# word> en
#
# Total playlist count is 1225...
# Term playlist count is 1225...
# word> e
#
# Total playlist count is 1569...
# Term playlist count is 1569...
# word> and
#
# Total playlist count is 1917...
# Term playlist count is 1917...
# word> s
#
# Total playlist count is 2467...
# Term playlist count is 2467...
# word> rodrigo
#
# Total playlist count is 3109...
# Term playlist count is 3109...
# word> olivia
#
# Total playlist count is 3798...
# Term playlist count is 3798...
# word> songs
#
# Total playlist count is 4283...
# Term playlist count is 4283...
# word> the
#
# Total playlist count is 4656...
# Term playlist count is 4656...
# word> of
#
# Total playlist count is 4996...
# Term playlist count is 4996...
# word> best
#
# Total playlist count is 5351...
# Term playlist count is 5351...
# word> hits
#
# Total playlist count is 5662...
# Term playlist count is 5662...
# word> top
#
# Total playlist count is 6066...
# Term playlist count is 6066...
# word> playlist
#
# Total playlist count is 6584...
# Term playlist count is 6584...
# word> rock
#
# Total playlist count is 6906...
# Term playlist count is 6906...
# word> all
#
# Total playlist count is 7373...
# Term playlist count is 7373...
# word> alle
#
# Total playlist count is 7964...
# Term playlist count is 7964...
# word> hörspiele
#
# Total playlist count is 8649...
# Term playlist count is 8649...
# word> die
#
# Total playlist count is 9166...
# Term playlist count is 9166...
# word> i
#
# Total playlist count is 9379...
# Term playlist count is 9379...
# word> is
#
# Total playlist count is 9481...
# Term playlist count is 9481...
# word> this
#
# Total playlist count is 9577...
# Term playlist count is 9577...
# word> folgen
#
# Total playlist count is 10294...
# Term playlist count is 0...
# word> summer
#
# Total playlist count is 10808...
# Term playlist count is 514...
# word> vibes
#
# Total playlist count is 11384...
# Term playlist count is 1090...
# word> chill
#
# Total playlist count is 11768...
# Term playlist count is 1474...
# word> music
#
# Total playlist count is 12105...
# Term playlist count is 1811...
# word> lofi
#
# Total playlist count is 12653...
# Term playlist count is 2359...
# word> beats
#
# Total playlist count is 13071...
# Term playlist count is 2777...
# word> to
#
# Total playlist count is 13505...
# Term playlist count is 3211...
# word> study
#
# Total playlist count is 13982...
# Term playlist count is 3688...
# word> sleep
#
# Total playlist count is 14403...
# Term playlist count is 4109...
# word> relax
#
# Total playlist count is 14822...
# Term playlist count is 4528...
# word> for
#
# Total playlist count is 15268...
# Term playlist count is 4974...
# word> relaxing
#
# Total playlist count is 15716...
# Term playlist count is 5422...
# word> piano
#
# Total playlist count is 16041...
# Term playlist count is 5747...
# word> hop
#
# Total playlist count is 16348...
# Term playlist count is 6054...
# word> hip
#
# Total playlist count is 16667...
# Term playlist count is 6373...
# word> rap
#
# Total playlist count is 17269...
# Term playlist count is 6975...
# word> polo
#
# Total playlist count is 17904...
# Term playlist count is 7610...
# word> g
#
# Total playlist count is 18330...
# Term playlist count is 8036...
# word> fi
#
# Total playlist count is 18764...
# Term playlist count is 8470...
# word> lo
#
# Total playlist count is 19133...
# Term playlist count is 8839...
# word> jazz
#
# Total playlist count is 19414...
# Term playlist count is 9120...
# word> rapstar
#
# Total playlist count is 20107...
# Term playlist count is 9813...
# word> polog
#
# Total playlist count is 20765...
# Term playlist count is 0...
# word> discography
#
# Total playlist count is 21031...
# Term playlist count is 266...
# word> complete
#
# Total playlist count is 21255...
# Term playlist count is 490...
# word> collection
#
# Total playlist count is 21533...
# Term playlist count is 768...
# word> full
#
# Total playlist count is 21963...
# Term playlist count is 1198...
# word> album
#
# Total playlist count is 22604...
# Term playlist count is 1839...
# word> colores
#
# Total playlist count is 23336...
# Term playlist count is 2571...
# word> de
#
# Total playlist count is 23733...
# Term playlist count is 2968...
# word> los
#
# Total playlist count is 24031...
# Term playlist count is 3266...
# word> sour
#
# Total playlist count is 24664...
# Term playlist count is 3899...
# word> olivas
#
# Total playlist count is 25381...
# Term playlist count is 4616...
# word> alfredo
#
# Total playlist count is 26070...
# Term playlist count is 5305...
# word> el
#
# Total playlist count is 26475...
# Term playlist count is 5710...
# word> la
#
# Total playlist count is 26879...
# Term playlist count is 6114...
# word> del
#
# Total playlist count is 27218...
# Term playlist count is 6453...
# word> alfredito
#
# Total playlist count is 27963...
# Term playlist count is 7198...
# word> exitos
#
# Total playlist count is 28510...
# Term playlist count is 7745...
# word> éxitos
#
# Total playlist count is 29058...
# Term playlist count is 8293...
# word> grandes
#
# Total playlist count is 29473...
# Term playlist count is 8708...
# word> mix
#
# Total playlist count is 29852...
# Term playlist count is 9087...
# word> grupo
#
# Total playlist count is 30430...
# Term playlist count is 9665...
# word> firme
#
# Repeated Term
#
# Total playlist count is 31124...
# Term playlist count is 0...
# word> soundtrack
#
# Total playlist count is 31477...
# Term playlist count is 353...
# word> soundtracks
#
# Total playlist count is 31943...
# Term playlist count is 819...
# word> movie
#
# Total playlist count is 32396...
# Term playlist count is 1272...
# word> anime
#
# Total playlist count is 32962...
# Term playlist count is 1838...
# word> ost
#
# Total playlist count is 33382...
# Term playlist count is 2258...
# word> openings
#
# Total playlist count is 33976...
# Term playlist count is 2852...
# word> endings
#
# Total playlist count is 34561...
# Term playlist count is 3437...
# word> no
#
# Total playlist count is 35008...
# Term playlist count is 3884...
# word> opening
#
# Total playlist count is 35593...
# Term playlist count is 4469...
# word> naruto
#
# Total playlist count is 36259...
# Term playlist count is 5135...
# word> ending
#
# Total playlist count is 36826...
# Term playlist count is 5702...
# word> osts
#
# Total playlist count is 37468...
# Term playlist count is 6344...
# word> op
#
# Total playlist count is 37958...
# Term playlist count is 6834...
# word> opm
#
# Total playlist count is 38469...
# Term playlist count is 7345...
# word> ed
#
# Total playlist count is 38876...
# Term playlist count is 7752...
# word> edm
#
# Total playlist count is 39276...
# Term playlist count is 8152...
# word> in
#
# Total playlist count is 39649...
# Term playlist count is 8525...
# word> sad
#
# Total playlist count is 40187...
# Term playlist count is 9063...
# word> love
#
# Total playlist count is 40615...
# Term playlist count is 9491...
# word> shippuden
#
# Repeated Term
#
# Total playlist count is 41342...
# Term playlist count is 0...
# word> hiphop
#
# Total playlist count is 41729...
# Term playlist count is 387...
# word> b
#
# Total playlist count is 42190...
# Term playlist count is 848...
# word> butter
#
# Total playlist count is 42924...
# Term playlist count is 1582...
# word> x
#
# Total playlist count is 43482...
# Term playlist count is 2140...
# word> bts
#
# Total playlist count is 44115...
# Term playlist count is 2773...
# word> m
#
# Total playlist count is 44569...
# Term playlist count is 3227...
# word> focus
#
# Total playlist count is 45119...
# Term playlist count is 3777...
# word> focused
#
# Total playlist count is 45798...
# Term playlist count is 4456...
# word> dance
#
# Total playlist count is 46161...
# Term playlist count is 4819...
# word> party
#
# Total playlist count is 46566...
# Term playlist count is 5224...
# word> like
#
# Total playlist count is 47103...
# Term playlist count is 5761...
# word> you
#
# Total playlist count is 47642...
# Term playlist count is 6300...
# word> your
#
# Total playlist count is 48134...
# Term playlist count is 6792...
# word> it
#
# Total playlist count is 48671...
# Term playlist count is 7329...
# word> me
#
# Total playlist count is 49031...
# Term playlist count is 7689...
# word> with
#
# Total playlist count is 49596...
# Term playlist count is 8254...
# word> re
#
# Total playlist count is 49996...
# Term playlist count is 8654...
# word> remix
#
# Total playlist count is 50489...
# Term playlist count is 9147...
# word> remixes
#
# Total playlist count is 50977...
# Term playlist count is 9635...
# word> melhores
# Total playlist count is 51307...
# Term playlist count is 9965...
# word> as
#
# Repeated Term
#
# Total playlist count is 51685...
# Term playlist count is 0...
# word> metal
#
# Total playlist count is 52012...
# Term playlist count is 327...
# word> metallica
#
# Total playlist count is 52614...
# Term playlist count is 929...
# word> heavy
#
# Total playlist count is 52961...
# Term playlist count is 1276...
# word> bass
#
# Total playlist count is 53381...
# Term playlist count is 1696...
# word> boosted
#
# Total playlist count is 54012...
# Term playlist count is 2327...
# word> car
#
# Total playlist count is 54475...
# Term playlist count is 2790...
# word> house
#
# Total playlist count is 54828...
# Term playlist count is 3143...
# word> deep
#
# Total playlist count is 55215...
# Term playlist count is 3530...
# word> workout
#
# Total playlist count is 55608...
# Term playlist count is 3923...
# word> gym
#
# Total playlist count is 56041...
# Term playlist count is 4356...
# word> motivation
#
# Total playlist count is 56440...
# Term playlist count is 4755...
# word> slap
#
# Total playlist count is 57073...
# Term playlist count is 5388...
# word> slaps
#
# Total playlist count is 57790...
# Term playlist count is 6105...
# word> motivational
#
# Total playlist count is 58358...
# Term playlist count is 6673...
# word> running
#
# Total playlist count is 58896...
# Term playlist count is 7211...
# word> cardio
#
# Total playlist count is 59453...
# Term playlist count is 7768...
# word> training
#
# Total playlist count is 59954...
# Term playlist count is 8269...
# word> bpm
#
# Total playlist count is 60478...
# Term playlist count is 8793...
# word> pop
#
# Total playlist count is 60822...
# Term playlist count is 9137...
# word> fitness
#
# Total playlist count is 61239...
# Term playlist count is 9554...
# word> para
#
# Total playlist count is 61680...
# Term playlist count is 9995...
# word> música
#
# Total playlist count is 62093...
# Term playlist count is 0...
# word> classical
#
# Total playlist count is 62397...
# Term playlist count is 304...
# word> baby
#
# Total playlist count is 62912...
# Term playlist count is 819...
# word> lil
#
# Total playlist count is 63514...
# Term playlist count is 1421...
# word> peep
#
# Total playlist count is 64189...
# Term playlist count is 2096...
# word> juice
#
# Total playlist count is 64814...
# Term playlist count is 2721...
# word> wrld
#
# Total playlist count is 65445...
# Term playlist count is 3352...
# word> unreleased
#
# Total playlist count is 66151...
# Term playlist count is 4058...
# word> xxxtentacion
#
# Total playlist count is 66743...
# Term playlist count is 4650...
# word> leaks
#
# Total playlist count is 67462...
# Term playlist count is 5369...
# word> carti
#
# Total playlist count is 68168...
# Term playlist count is 6075...
# word> playboi
#
# Total playlist count is 68865...
# Term playlist count is 6772...
# word> uzi
#
# Total playlist count is 69519...
# Term playlist count is 7426...
# word> vert
#
# Total playlist count is 70160...
# Term playlist count is 8067...
# word> ft
#
# Total playlist count is 70747...
# Term playlist count is 8654...
# word> trippie
#
# Total playlist count is 71444...
# Term playlist count is 9351...
# word> redd
#
# Total playlist count is 72070...
# Term playlist count is 9977...
# word> feat
#
# Repeated Term
#
# Total playlist count is 72527...
# Term playlist count is 0...
# word> country
#
# Total playlist count is 72836...
# Term playlist count is 309...
# word> july
#
# Total playlist count is 73493...
# Term playlist count is 966...
# word> th
#
# Total playlist count is 73651...
# Term playlist count is 1124...
# word> fourth
#
# Total playlist count is 74386...
# Term playlist count is 1859...
# word> patriotic
#
# Total playlist count is 75127...
# Term playlist count is 2600...
# word> american
#
# Total playlist count is 75600...
# Term playlist count is 3073...
# word> americana
#
# Total playlist count is 76206...
# Term playlist count is 3679...
# word> americanas
#
# Total playlist count is 76830...
# Term playlist count is 4303...
# word> baladas
#
# Total playlist count is 77334...
# Term playlist count is 4807...
# word> folk
#
# Total playlist count is 77890...
# Term playlist count is 5363...
# word> taylor
#
# Total playlist count is 78508...
# Term playlist count is 5981...
# word> swift
#
# Total playlist count is 79142...
# Term playlist count is 6615...
# word> folklore
#
# Total playlist count is 79805...
# Term playlist count is 7278...
# word> evermore
#
# Total playlist count is 80548...
# Term playlist count is 8021...
# word> version
#
# Total playlist count is 81052...
# Term playlist count is 8525...
# word> clean
#
# Total playlist count is 81508...
# Term playlist count is 8981...
# word> español
#
# Total playlist count is 81894...
# Term playlist count is 9367...
# word> versions
#
# Total playlist count is 82363...
# Term playlist count is 9836...
# word> covers
#
# Total playlist count is 82695...
# Term playlist count is 0...
# word> blues
#
# Total playlist count is 82977...
# Term playlist count is 282...
# word> soul
#
# Total playlist count is 83304...
# Term playlist count is 609...
# word> r
#
# Total playlist count is 83754...
# Term playlist count is 1059...
# word> radio
#
# Total playlist count is 84068...
# Term playlist count is 1373...
# word> fm
#
# Total playlist count is 84568...
# Term playlist count is 1873...
# word> kiss
#
# Total playlist count is 85141...
# Term playlist count is 2446...
# word> kisses
#
# Total playlist count is 85873...
# Term playlist count is 3178...
# word> my
#
# Total playlist count is 86413...
# Term playlist count is 3718...
# word> heart
#
# Total playlist count is 86918...
# Term playlist count is 4223...
# word> on
#
# Total playlist count is 87386...
# Term playlist count is 4691...
# word> only
#
# Total playlist count is 87939...
# Term playlist count is 5244...
# word> good
#
# Total playlist count is 88401...
# Term playlist count is 5706...
# word> feel
#
# Total playlist count is 88951...
# Term playlist count is 6256...
# word> feeling
#
# Total playlist count is 89552...
# Term playlist count is 6857...
# word> feelings
#
# Total playlist count is 90196...
# Term playlist count is 7501...
# word> feels
#
# Total playlist count is 90793...
# Term playlist count is 8098...
# word> that
#
# Total playlist count is 91333...
# Term playlist count is 8638...
# word> make
#
# Total playlist count is 91888...
# Term playlist count is 9193...
# word> but
#
# Total playlist count is 92564...
# Term playlist count is 9869...
# word> t
#
# Repeated Term
#
# Repeated Term
#
# Repeated Term
#
# Repeated Term
#
# Repeated Term
#
# Repeated Term
#
# Total playlist count is 92909...
# Term playlist count is 0...
# word> mood
#
# Total playlist count is 93429...
# Term playlist count is 520...
# word> bad
#
# Total playlist count is 93970...
# Term playlist count is 1061...
# word> bunny
#
# Total playlist count is 94491...
# Term playlist count is 1582...
# word> bitch
#
# Total playlist count is 95102...
# Term playlist count is 2193...
# word> bitches
#
# Total playlist count is 95785...
# Term playlist count is 2876...
# word> badass
#
# Total playlist count is 96453...
# Term playlist count is 3544...
# word> get
#
# Total playlist count is 96919...
# Term playlist count is 4010...
# word> getting
#
# Total playlist count is 97492...
# Term playlist count is 4583...
# word> ready
#
# Total playlist count is 97974...
# Term playlist count is 5065...
# word> pov
#
# Total playlist count is 98711...
# Term playlist count is 5802...
# word> ur
#
# Total playlist count is 99244...
# Term playlist count is 6335...
# word> dating
#
# Total playlist count is 99984...
# Term playlist count is 7075...
# word> are
#
# Total playlist count is 100457...
# Term playlist count is 7548...
# word> we
#
# Total playlist count is 100944...
# Term playlist count is 8035...
# word> up
#
# Total playlist count is 101326...
# Term playlist count is 8417...
# word> by
#
# Total playlist count is 101784...
# Term playlist count is 8875...
# word> urban
#
# Total playlist count is 102273...
# Term playlist count is 9364...
# word> urbano
#
# Total playlist count is 102839...
# Term playlist count is 9930...
# word> am
#
# Total playlist count is 103313...
# Term playlist count is 0...
# word> hype
#
# Total playlist count is 103867...
# Term playlist count is 554...
# word> hyperpop
#
# Total playlist count is 104608...
# Term playlist count is 1295...
# word> glitchcore
#
# Total playlist count is 105355...
# Term playlist count is 2042...
# word> weirdcore
#
# Total playlist count is 106105...
# Term playlist count is 2792...
# word> dreamcore
#
# Total playlist count is 106855...
# Term playlist count is 3542...
# word> traumacore
#
# Total playlist count is 107605...
# Term playlist count is 4292...
# word> webcore
# Total playlist count is 107961...
# Term playlist count is 4648...
# word> kidcore
#
# Total playlist count is 108564...
# Term playlist count is 5251...
# word> internetcore
#
# Total playlist count is 108736...
# Term playlist count is 5423...
# word> oddcore
#
# Total playlist count is 108891...
# Term playlist count is 5578...
# word> nostalgiacore
#
# Total playlist count is 109019...
# Term playlist count is 5706...
# word> o
#
# Total playlist count is 109422...
# Term playlist count is 6109...
# word> w
#
# Total playlist count is 109862...
# Term playlist count is 6549...
# word> go
#
# Total playlist count is 110271...
# Term playlist count is 6958...
# word> indie
#
# Total playlist count is 110668...
# Term playlist count is 7355...
# word> d
#
# Total playlist count is 111095...
# Term playlist count is 7782...
# word> dream
#
# Total playlist count is 111624...
# Term playlist count is 8311...
# word> dreams
#
# Total playlist count is 112195...
# Term playlist count is 8882...
# word> sweet
#
# Total playlist count is 112781...
# Term playlist count is 9468...
# word> night
#
# Total playlist count is 113298...
# Term playlist count is 9985...
# word> nights
#
# Total playlist count is 113875...
# Term playlist count is 0...
# word> spotify
#
# Total playlist count is 114292...
# Term playlist count is 417...
# word> wap
#
# Total playlist count is 115022...
# Term playlist count is 1147...
# word> joe
#
# Total playlist count is 115577...
# Term playlist count is 1702...
# word> joel
#
# Total playlist count is 116254...
# Term playlist count is 2379...
# word> billy
#
# Total playlist count is 116883...
# Term playlist count is 3008...
# word> joey
#
# Total playlist count is 117586...
# Term playlist count is 3711...
# word> joeys
#
# Total playlist count is 118333...
# Term playlist count is 4458...
# word> fetty
#
# Total playlist count is 119060...
# Term playlist count is 5185...
# word> trap
#
# Total playlist count is 119523...
# Term playlist count is 5648...
# word> christmas
#
# Total playlist count is 119887...
# Term playlist count is 6012...
# word> queen
#
# Total playlist count is 120406...
# Term playlist count is 6531...
# word> queens
#
# Total playlist count is 121088...
# Term playlist count is 7213...
# word> kings
#
# Total playlist count is 121684...
# Term playlist count is 7809...
# word> live
#
# Total playlist count is 122221...
# Term playlist count is 8346...
# word> greatest
#
# Total playlist count is 122547...
# Term playlist count is 8672...
# word> joelma
#
# Total playlist count is 123153...
# Term playlist count is 9278...
# word> calypso
#
# Total playlist count is 123865...
# Term playlist count is 9990...
# word> do
#
# Total playlist count is 124302...
# Term playlist count is 0...
# word> vibe
#
# Total playlist count is 124887...
# Term playlist count is 585...
# word> happy
#
# Total playlist count is 125389...
# Term playlist count is 1087...
# word> morning
#
# Total playlist count is 125871...
# Term playlist count is 1569...
# word> mornings
#
# Total playlist count is 126513...
# Term playlist count is 2211...
# word> sunday
#
# Total playlist count is 127020...
# Term playlist count is 2718...
# word> coffee
#
# Total playlist count is 127506...
# Term playlist count is 3204...
# word> shop
#
# Total playlist count is 128092...
# Term playlist count is 3790...
# word> shopping
#
# Total playlist count is 128811...
# Term playlist count is 4509...
# word> star
#
# Total playlist count is 129308...
# Term playlist count is 5006...
# word> stars
#
# Total playlist count is 129894...
# Term playlist count is 5592...
# word> at
#
# Total playlist count is 130445...
# Term playlist count is 6143...
# word> starring
#
# Total playlist count is 131071...
# Term playlist count is 6769...
# word> ceiling
#
# Total playlist count is 131794...
# Term playlist count is 7492...
# word> us
#
# Total playlist count is 132320...
# Term playlist count is 8018...
# word> hold
#
# Total playlist count is 132934...
# Term playlist count is 8632...
# word> can
#
# Total playlist count is 133385...
# Term playlist count is 9083...
# word> macklemore
#
# Total playlist count is 134122...
# Term playlist count is 9820...
# word> usa
#
# Total playlist count is 134729...
# Term playlist count is 0...
# word> musical
#
# Total playlist count is 135130...
# Term playlist count is 401...
# word> musicals
#
# Total playlist count is 135829...
# Term playlist count is 1100...
# word> disney
#
# Total playlist count is 136344...
# Term playlist count is 1615...
# word> broadway
#
# Total playlist count is 137004...
# Term playlist count is 2275...
# word> bops
#
# Total playlist count is 137635...
# Term playlist count is 2906...
# word> old
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# ~/anaconda3/lib/python3.8/http/client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# ~/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# ~/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     402             if read is False or not self._is_method_retryable(method):
# --> 403                 raise six.reraise(type(error), error, _stacktrace)
#     404             elif read is not None:
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     734                 raise value.with_traceback(tb)
# --> 735             raise value
#     736         finally:
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     429             raise
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     334         if isinstance(err, SocketTimeout):
# --> 335             raise ReadTimeoutError(
#     336                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-7-2283ef8f827e> in <module>
#      16                     print('word>', word)
#      17                     print("")
# ---> 18                     for playlist in find_playlists(session, word):
#      19                         if playlist['id'] in playlists:
#      20                             dupes += 1
#
# <ipython-input-3-e72e135af9d1> in find_playlists(session, w, max_count)
#      11             while tries > 0:
#      12                 try:
# ---> 13                     res = session.next(res['playlists'])
#      14                     tries = 0
#      15                 except SpotifyException as e:
#
# ~/anaconda3/lib/python3.8/site-packages/spotipy/client.py in next(self, result)
#     313         """
#     314         if result["next"]:
# --> 315             return self._get(result["next"])
#     316         else:
#     317             return None
#
# ~/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     289             kwargs.update(args)
#     290
# --> 291         return self._internal_call("GET", url, payload, kwargs)
#     292
#     293     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     238
#     239         try:
# --> 240             response = self._session.request(
#     241                 method, url, headers=headers, proxies=self.proxies,
#     242                 timeout=self.requests_timeout, **args
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='api.spotify.com', port=443): Read timed out. (read timeout=5)

# %% [markdown]
# ## Get Tracks for New Playlists

# %%
# Get collected tracks
conn = sqlite3.connect('data/songs.db')
c = conn.cursor()
c.execute("SELECT id FROM songs")

sql_tracks = c.fetchall()

# %%
# Clean tuple format from SQL response
tracks_seen = set()
for i in range(len(sql_tracks)):
    tracks_seen.add(sql_tracks[i][0])

# %%
len(new_playlists.keys())
# Out:
# 95726

# %%
# Retrieve new tracks and save them
count = 0
with open('data/playlists.ndjson', 'a') as fout_playlists:
    with open('data/songs_ids.txt', 'a') as fout_song_ids:
        for playlist in tqdm.tqdm_notebook(new_playlists.values()):
            try:
                fout_playlists.write(json.dumps(playlist) + '\n')
                track_ids = []
                for track in track_yielder(session, playlist):
                    track_id = track['id']
                    if not track_id:
                        continue
                    if not track_id in tracks_seen:
                        c.execute("INSERT INTO songs VALUES (?, ?, ?)", 
                                  (track['id'], track['name'], track['artists'][0]['name']))
                    track_ids.append(track_id)
                    tracks_seen.add(track_id)
                fout_song_ids.write(' '.join(track_ids) + '\n')
                conn.commit()
            except:
                session = spotipy.Spotify(auth_manager = spotipy.SpotifyOAuth(
                    client_id = client_id,
                    client_secret = client_secret,
                    scope = scope,
                    username = '9qwpnpaxd9zbx1q1jrdh9bxz1',
                    redirect_uri = redirect_uri
                ))
                count += 1
                print(f"Playlist Failures: {count}")
                print(playlist)
conn.commit()
# Out:
# <ipython-input-15-adfc1d2a5884>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for playlist in tqdm.tqdm_notebook(new_playlists.values()):
# HBox(children=(FloatProgress(value=0.0, max=95726.0), HTML(value='')))
# Playlist Failures: 1
# {'owner': 'zeeicktempeer', 'name': 'POLOBOYS', 'id': '0kUdxXsgYG2aUOD0AS0bfX'}
# HTTP Error for GET to https://api.spotify.com/v1/playlists/6WsFVqMU2qSped5Bpfcjvc/tracks returned 404 due to Not found.
# Playlist Failures: 2
# {'owner': 'u2u66mhrb4qvg6v1noh2xzj8m', 'name': 'carti’s gf', 'id': '6WsFVqMU2qSped5Bpfcjvc'}
# HTTP Error for GET to https://api.spotify.com/v1/playlists/7GPloZvmAgzpyjHfpvNv1d/tracks returned 404 due to Not found.
# Playlist Failures: 3
# {'owner': 'y3n9g32vu16eek7v2s3n5cp88', 'name': 'dreams playlist (h word)', 'id': '7GPloZvmAgzpyjHfpvNv1d'}
# Playlist Failures: 4
# {'owner': 'joseph1384', 'name': 'joeys country ', 'id': '5BR968UOijm253AqNpnIXO'}
# HTTP Error for GET to https://api.spotify.com/v1/playlists/2xzRZDfhhKaVGKKPAumHp9/tracks returned 404 due to Not found.
# Playlist Failures: 5
# {'owner': '0tiuwqx8xxeoqqv0t1y0qfymx', 'name': 'Ceiling ', 'id': '2xzRZDfhhKaVGKKPAumHp9'}
# Playlist Failures: 6
# {'owner': '1111831730', 'name': 'Rat holder🚜', 'id': '5c4DQX6zpZx7s5FervWxe9'}
# Playlist Failures: 7
# {'owner': 'hamelinck', 'name': 'Drill USA: NY Edition (Brooklyn Drill)', 'id': '1xxUda8w0R1fPsP2ugT3aY'}
# Playlist Failures: 8
# {'owner': 'willoughbyseago', 'name': 'MUSICALS GALORE', 'id': '4dv2aVt0WSzzU8pBwlcAnJ'}
