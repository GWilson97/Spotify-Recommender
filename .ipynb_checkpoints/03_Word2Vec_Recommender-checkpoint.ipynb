# %% [markdown]
# ## Import Packages

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /home/grant/.pyenv/versions/3.7.2/lib/python3.7/site-packages (3.8.3)
# Requirement already satisfied: six>=1.5.0 in /home/grant/.pyenv/versions/3.7.2/lib/python3.7/site-packages (from gensim) (1.15.0)
# Requirement already satisfied: numpy>=1.11.3 in /home/grant/.pyenv/versions/3.7.2/lib/python3.7/site-packages (from gensim) (1.19.4)
# Requirement already satisfied: smart-open>=1.8.1 in /home/grant/.pyenv/versions/3.7.2/lib/python3.7/site-packages (from gensim) (4.0.1)
# Requirement already satisfied: scipy>=0.18.1 in /home/grant/.pyenv/versions/3.7.2/lib/python3.7/site-packages (from gensim) (1.5.4)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import spotipy

import json
import gensim
from operator import itemgetter

import sqlite3
import creds

# %% [markdown]
# ## Define Functions

# %%
def find_song(song_name, limit=20):
    c = conn.cursor()
    c.execute("SELECT * FROM songs WHERE UPPER(name) LIKE '%" + song_name + "%'")
    res = sorted(((x, model.wv.vocab[x[0]].count) 
                  for x in c.fetchall() if x[0] in model.wv.vocab), key=itemgetter(-1), reverse = True)
    return [*res][:limit]

# %%
def suggest_songs(song_id):
    c = conn.cursor()
    similar = dict(model.wv.most_similar([song_id], topn = 25))
    song_ids = ', '.join(("'%s'" % x) for x in similar.keys())
    c.execute("SELECT * FROM songs WHERE id in (%s)" % song_ids)
    res = sorted((rec + (similar[rec[0]],) for rec in c.fetchall()), 
                 key=itemgetter(-1),
                 reverse=True)
    for i in res:
        print(i)
        
    return list(similar)

# %% [markdown]
# ## Class to Split Tracks

# %%
# Create a class for breaking up model vocab
class WordSplitter(object):
    def __init__(self, filename):
        self.filename = filename
 
    def __iter__(self):
        with open(self.filename) as fin:
            for line in fin:
                yield line.split()

# %% [markdown]
# ## Instantiate Word2Vec Model

# %%
# Load Pre-trained model
model = gensim.models.word2vec.Word2Vec.load("data/word2vec.model")

# %%
# Instantiate Word2Vec model with songs
model = gensim.models.Word2Vec(WordSplitter("data/songs_ids.txt"), min_count = 100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-25126f188ee2> in <module>
#       1 # Instantiate Word2Vec model with songs
# ----> 2 model = gensim.models.Word2Vec(WordSplitter("data/songs_ids.txt"), min_count = 100)
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/word2vec.py in __init__(self, sentences, corpus_file, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, max_final_vocab)
#     595         self.trainables = Word2VecTrainables(seed=seed, vector_size=size, hashfxn=hashfxn)
#     596
# --> 597         super(Word2Vec, self).__init__(
#     598             sentences=sentences, corpus_file=corpus_file, workers=workers, vector_size=size, epochs=iter,
#     599             callbacks=callbacks, batch_words=batch_words, trim_rule=trim_rule, sg=sg, alpha=alpha, window=window,
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/base_any2vec.py in __init__(self, sentences, corpus_file, workers, vector_size, epochs, callbacks, batch_words, trim_rule, sg, alpha, window, seed, hs, negative, ns_exponent, cbow_mean, min_alpha, compute_loss, **kwargs)
#     743                 raise TypeError("You can't pass a generator as the sentences argument. Try a sequence.")
#     744
# --> 745             self.build_vocab(sentences=sentences, corpus_file=corpus_file, trim_rule=trim_rule)
#     746             self.train(
#     747                 sentences=sentences, corpus_file=corpus_file, total_examples=self.corpus_count,
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/base_any2vec.py in build_vocab(self, sentences, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     919
#     920         """
# --> 921         total_words, corpus_count = self.vocabulary.scan_vocab(
#     922             sentences=sentences, corpus_file=corpus_file, progress_per=progress_per, trim_rule=trim_rule)
#     923         self.corpus_count = corpus_count
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/word2vec.py in scan_vocab(self, sentences, corpus_file, progress_per, workers, trim_rule)
#    1401             sentences = LineSentence(corpus_file)
#    1402
# -> 1403         total_words, corpus_count = self._scan_vocab(sentences, progress_per, trim_rule)
#    1404
#    1405         logger.info(
#
# ~/anaconda3/lib/python3.8/site-packages/gensim/models/word2vec.py in _scan_vocab(self, sentences, progress_per, trim_rule)
#    1370         vocab = defaultdict(int)
#    1371         checked_string_types = 0
# -> 1372         for sentence_no, sentence in enumerate(sentences):
#    1373             if not checked_string_types:
#    1374                 if isinstance(sentence, string_types):
#
# <ipython-input-4-b5e710ebd093> in __iter__(self)
#       7         with open(self.filename) as fin:
#       8             for line in fin:
# ----> 9                 yield line.split()
#
# KeyboardInterrupt:

# %%
# Save Model
model.save("data/word2vec.model")

# %% [markdown]
# ## Track Identification and Recommendation

# %%
# Connect to the database of songs and find frequency for tracks
conn = sqlite3.connect('data/songs.db')

for t in find_song('almost maybes'):
    print(*t)
# Out:
# ('14JFKtBSqefxfMiKhq6JT8', 'Almost Maybes', 'Jordan Davis') 270

# %%
# Suggest songs
rec_tracks = suggest_songs('14JFKtBSqefxfMiKhq6JT8')
# Out:
# ('1OTX8FOeKJt1v9mIxuF8sc', 'Long Live', 'Florida Georgia Line', 0.9618141651153564)
# ('3t2xlkvPsrcyia0eBaCZ53', 'Every Other Memory', 'Ryan Hurd', 0.9608017206192017)
# ('21HxYsyuuXZNqB1Dme5PQN', 'Wildfire', 'Nate Smith', 0.9562852382659912)
# ('36ISlLb12gKuCCVTYXC0gb', 'Beers And Sunshine', 'Darius Rucker', 0.9505412578582764)
# ('1irAliF0T8sLIOPJp6n7rU', 'Single Saturday Night', 'Cole Swindell', 0.950253963470459)
# ('4RN6OApAESI3Sh0gf5iuAM', 'Worship You', 'Kane Brown', 0.9493966698646545)
# ('2DwbFtfC6sXBiVDPmju8Dd', 'Happy Anywhere (feat. Gwen Stefani)', 'Blake Shelton', 0.9452993869781494)
# ('0nGXi46VcQQ56ZJR428MKS', 'Does To Me (feat. Eric Church)', 'Luke Combs', 0.9448864459991455)
# ('5nra2uQhiaYKKpemgiDNC3', 'GIVE HEAVEN SOME HELL', 'HARDY', 0.9433592557907104)
# ('2Q04BmXs7Sr7ThizTmERj6', 'Young Once', 'Sam Hunt', 0.942757248878479)
# ('3zxAw8PaqpeGZ3Pakkxv3J', 'Without You', 'Luke Combs', 0.9418151378631592)
# ('0Al3wN3keprGTSgG8NBwjr', 'I Hope You’re Happy Now', 'Carly Pearce', 0.9417145252227783)
# ('3YuvAPidBWldqjagOryo40', 'I Called Mama', 'Tim McGraw', 0.9410004019737244)
# ('0eBXyY4SatzpE7opnzgXvz', 'More Than My Hometown', 'Morgan Wallen', 0.9407626986503601)
# ('4QhFrBkJ3Rqx66Xs8xwH8o', 'If It Wasn’t For Trucks', 'Riley Green', 0.9402647018432617)
# ('693NFnfJZt16AFDaZqlflo', 'Done', 'Chris Janson', 0.9399125576019287)
# ('1Jn0osXy1WcDyniHgs67jT', 'Broken Up', 'Mitchell Tenpenny', 0.9394048452377319)
# ('58DvikiJcEjow3Skg80yxX', 'The Man Who Loves You The Most', 'Zac Brown Band', 0.9380189180374146)
# ('1B4kH07ncrQh2pNDV6P60P', 'Chapters', 'Brett Young', 0.9321112632751465)
# ('0nYvjcSlCgjcwogQAwIwNp', "Lovin' On You", 'Luke Combs', 0.9316555857658386)
# ('34slXA5D75T5S0dwYYRd4J', 'Without You', 'Luke Combs', 0.9306018352508545)
# ('0jcZ1uIHmvh6Is9T6hXOUk', 'The Other Guy', 'Luke Combs', 0.9296590685844421)
# ('3aMUiKCIXJeurR5ppEMJZD', 'Six Feet Apart', 'Luke Combs', 0.9294487237930298)
# ('3ySLzrN7950dpf1ncttONO', 'Lady', 'Brett Young', 0.9289016723632812)
# ('4Ar1v62ri7sTbJ8XObrM2k', 'Maybe We Will', 'Noah Schnacky', 0.9285304546356201)

# %% [markdown]
# ## Create Recommended Playlists

# %%
# Create Spotify Session
session = creds.session

# %%
session.current_user_playlists()
# Out:
# {'href': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6As3FfCq3n7Njj2Xk8ecJu'},
#    'href': 'https://api.spotify.com/v1/playlists/6As3FfCq3n7Njj2Xk8ecJu',
#    'id': '6As3FfCq3n7Njj2Xk8ecJu',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2734b0135b555e5295dc8e28af9ab67616d0000b273b5b3f33183d5ae293b8d24fbab67616d0000b273dfdefe159fd457b152e9d367ab67616d0000b273f9908a8a756ecfce0d7d63dd',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2734b0135b555e5295dc8e28af9ab67616d0000b273b5b3f33183d5ae293b8d24fbab67616d0000b273dfdefe159fd457b152e9d367ab67616d0000b273f9908a8a756ecfce0d7d63dd',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b2734b0135b555e5295dc8e28af9ab67616d0000b273b5b3f33183d5ae293b8d24fbab67616d0000b273dfdefe159fd457b152e9d367ab67616d0000b273f9908a8a756ecfce0d7d63dd',
#      'width': 60}],
#    'name': 'Isabelle Jams',
#    'owner': {'display_name': 'GWilson',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/9qwpnpaxd9zbx1q1jrdh9bxz1'},
#     'href': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'id': '9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'type': 'user',
#     'uri': 'spotify:user:9qwpnpaxd9zbx1q1jrdh9bxz1'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTEsYTA2OTdjNmI3NDdhZGFmNzgxMjFmNmY2ZWU4N2QwNTNjZDI3OGE2Yg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6As3FfCq3n7Njj2Xk8ecJu/tracks',
#     'total': 10},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6As3FfCq3n7Njj2Xk8ecJu'},
#   {'collaborative': False,
#    'description': "Introducing Summer Breakouts, featuring exciting artists and songs to soundtrack your summer '21. Cover: Tai Verdes",
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXbAmP7AvWeiR'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXbAmP7AvWeiR',
#    'id': '37i9dQZF1DXbAmP7AvWeiR',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000034f6e0a6521df7398dbddf61d',
#      'width': None}],
#    'name': 'Summer Breakouts',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MTYyNTY4OTQxMSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXbAmP7AvWeiR/tracks',
#     'total': 70},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DXbAmP7AvWeiR'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3elNy7Qr30Upve8aRuVqCV'},
#    'href': 'https://api.spotify.com/v1/playlists/3elNy7Qr30Upve8aRuVqCV',
#    'id': '3elNy7Qr30Upve8aRuVqCV',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b27330c9fa6efba5a91832325953ab67616d0000b273560ea575b1d7f32eda29b0c9ab67616d0000b273710444d313a55d9f53dbea6eab67616d0000b273e95af957e661f22cff3f28ac',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b27330c9fa6efba5a91832325953ab67616d0000b273560ea575b1d7f32eda29b0c9ab67616d0000b273710444d313a55d9f53dbea6eab67616d0000b273e95af957e661f22cff3f28ac',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b27330c9fa6efba5a91832325953ab67616d0000b273560ea575b1d7f32eda29b0c9ab67616d0000b273710444d313a55d9f53dbea6eab67616d0000b273e95af957e661f22cff3f28ac',
#      'width': 60}],
#    'name': 'Jams',
#    'owner': {'display_name': 'GWilson',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/9qwpnpaxd9zbx1q1jrdh9bxz1'},
#     'href': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'id': '9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'type': 'user',
#     'uri': 'spotify:user:9qwpnpaxd9zbx1q1jrdh9bxz1'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MixiNThjZDJkMDRkMGIyNTQ4MjVkZjFiNmE4ZmJkMTBmZjNiNTM0NjAx',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3elNy7Qr30Upve8aRuVqCV/tracks',
#     'total': 25},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3elNy7Qr30Upve8aRuVqCV'},
#   {'collaborative': False,
#    'description': 'The best side! Cover: Kendrick Lamar\n',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9sQDbOMReFI'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9sQDbOMReFI',
#    'id': '37i9dQZF1DX9sQDbOMReFI',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f000000039f2b4f56fdd7b8175c988cc2',
#      'width': None}],
#    'name': 'I Love My West Coast Classics',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MTYyNTI2Nzg3OSwwMDAwMDAxMTAwMDAwMTdhNjk4M2JjYWIwMDAwMDE3YTY1YjUxMzNl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9sQDbOMReFI/tracks',
#     'total': 50},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX9sQDbOMReFI'},
#   {'collaborative': False,
#    'description': 'Our favorite parade-route jams to bring the sounds of Carnival into your cars and living rooms. ',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1wsSrawVf8n52Hb9SPglN0'},
#    'href': 'https://api.spotify.com/v1/playlists/1wsSrawVf8n52Hb9SPglN0',
#    'id': '1wsSrawVf8n52Hb9SPglN0',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb03bf5c825360f0fddfd5c724',
#      'width': None}],
#    'name': 'Mardi Gras Music',
#    'owner': {'display_name': 'New Orleans Tourism',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/gxrlv0b973yp8upknowbqpm2h'},
#     'href': 'https://api.spotify.com/v1/users/gxrlv0b973yp8upknowbqpm2h',
#     'id': 'gxrlv0b973yp8upknowbqpm2h',
#     'type': 'user',
#     'uri': 'spotify:user:gxrlv0b973yp8upknowbqpm2h'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MjAsNmIzY2UyNmZmODMwNTI3ZWU2YjQ5OTA5MWQzMzcyYTk0ZWY4ODRlZQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1wsSrawVf8n52Hb9SPglN0/tracks',
#     'total': 16},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1wsSrawVf8n52Hb9SPglN0'},
#   {'collaborative': False,
#    'description': 'This is Luke Combs. The essential tracks, all in one playlist.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DZ06evO49lTA4'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO49lTA4',
#    'id': '37i9dQZF1DZ06evO49lTA4',
#    'images': [{'height': None,
#      'url': 'https://thisis-images.scdn.co/37i9dQZF1DZ06evO49lTA4-large.jpg',
#      'width': None}],
#    'name': 'This Is Luke Combs',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjcwOTQ1MjUsMDAwMDAwMDA2OGFhZTNmN2IyMDgzYTA5OTIzOWI3OTMyOGJiMTRkYQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO49lTA4/tracks',
#     'total': 35},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DZ06evO49lTA4'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4bUEBS17xIhOhBAUrDlv9C'},
#    'href': 'https://api.spotify.com/v1/playlists/4bUEBS17xIhOhBAUrDlv9C',
#    'id': '4bUEBS17xIhOhBAUrDlv9C',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b

#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b273338b805b93667d7e1daabc79ab67616d0000b2735a38bd36056b909ed607689dab67616d0000b2739cbbbdd15ff65aaab9a611b0ab67616d0000b273d41fec800fa501c5bc623083',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b273338b805b93667d7e1daabc79ab67616d0000b2735a38bd36056b909ed607689dab67616d0000b2739cbbbdd15ff65aaab9a611b0ab67616d0000b273d41fec800fa501c5bc623083',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b273338b805b93667d7e1daabc79ab67616d0000b2735a38bd36056b909ed607689dab67616d0000b2739cbbbdd15ff65aaab9a611b0ab67616d0000b273d41fec800fa501c5bc623083',
#      'width': 60}],
#    'name': 'Somewhat Omniscient Neuropath Generator',
#    'owner': {'display_name': 'GWilson',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/9qwpnpaxd9zbx1q1jrdh9bxz1'},
#     'href': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'id': '9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'type': 'user',
#     'uri': 'spotify:user:9qwpnpaxd9zbx1q1jrdh9bxz1'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MywxMTI3ZDJiYjhiOTk5NmQ5ZWM2MTdhYjA2YjU1NjgzY2QxNzU5NTE3',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4XY3K1Z3TleVSpVES7RYBa/tracks',
#     'total': 25},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4XY3K1Z3TleVSpVES7RYBa'},
#   {'collaborative': False,
#    'description': 'Follow this playlist to hear current single “Forever After All,” as well as songs from my new deluxe album What You See Ain’t Always What You Get + more!',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5sEM3oiygrXyRP2USzyDGs'},
#    'href': 'https://api.spotify.com/v1/playlists/5sEM3oiygrXyRP2USzyDGs',
#    'id': '5sEM3oiygrXyRP2USzyDGs',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb1b49def0bafc1848ceeeb112',
#      'width': None}],
#    'name': 'Luke Combs – Forever After All + More Hits',
#    'owner': {'display_name': 'Luke Combs',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/lukecombs'},
#     'href': 'https://api.spotify.com/v1/users/lukecombs',
#     'id': 'lukecombs',
#     'type': 'user',
#     'uri': 'spotify:user:lukecombs'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'Mzk3LDM1ZmQ4YzhhZWMxNWIzMTFlZTBmODliZWVmMGEyZmMxNDdmOTczZDA=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/5sEM3oiygrXyRP2USzyDGs/tracks',
#     'total': 52},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:5sEM3oiygrXyRP2USzyDGs'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/194WZhsrFNi9lxjXNjFRcP'},
#    'href': 'https://api.spotify.com/v1/playlists/194WZhsrFNi9lxjXNjFRcP',
#    'id': '194WZhsrFNi9lxjXNjFRcP',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb2849471b87a583dd2259ead6',
#      'width': None}],
#    'name': 'Live At Jazz Fest',
#    'owner': {'display_name': 'JamBase',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/jambase'},
#     'href': 'https://api.spotify.com/v1/users/jambase',
#     'id': 'jambase',
#     'type': 'user',
#     'uri': 'spotify:user:jambase'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'Myw2NmZiZjZlZGNhMTg5Yzc5ZmE4NzE3OTZjMzk1MDE2NTU5OGMwNTUw',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/194WZhsrFNi9lxjXNjFRcP/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:194WZhsrFNi9lxjXNjFRcP'},
#   {'collaborative': False,
#    'description': 'TUNA TASTES GOOD. LET&#x27;S GET US SOME TUNA.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/34ao0xQdobvvSwTMMPzc9A'},
#    'href': 'https://api.spotify.com/v1/playlists/34ao0xQdobvvSwTMMPzc9A',
#    'id': '34ao0xQdobvvSwTMMPzc9A',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb8e1456090ad04b2f39eedd13',
#      'width': None}],
#    'name': "Erg Bangers - Top 64 - PBC Men's Sweep",
#    'owner': {'display_name': 'Peter Daniel Clements',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1211637261'},
#     'href': 'https://api.spotify.com/v1/users/1211637261',
#     'id': '1211637261',
#     'type': 'user',
#     'uri': 'spotify:user:1211637261'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'NjYsMzYxMGM3NGY5YTYwYTY3YjllN2FkNzZiN2RjM2U4NWRmZGFiZmU2Mg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists

#    'type': 'playlist',
#    'uri': 'spotify:playlist:3Of1ZrbDOpx3MGYc697eJs'},
#   {'collaborative': False,
#    'description': 'Here&#x27;s row2k&#x27;s list of the 15 erg songs for your winter 2019-2020 erg playlist and listening pleasure.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7Fc3N49QLTDPAZcALQr5lw'},
#    'href': 'https://api.spotify.com/v1/playlists/7Fc3N49QLTDPAZcALQr5lw',
#    'id': '7Fc3N49QLTDPAZcALQr5lw',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebbc100d7e46c527325e7e18e09',
#      'width': None}],
#    'name': "row2k's Winter Erg Playlist - 2019-2020",
#    'owner': {'display_name': 'row2k',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/row2k'},
#     'href': 'https://api.spotify.com/v1/users/row2k',
#     'id': 'row2k',
#     'type': 'user',
#     'uri': 'spotify:user:row2k'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MzEsMDFkOGQwOWYwZWFhMTliYTIwNmFkMWEzZTY2Mjg4NmQ5NjdjYmYwYw==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7Fc3N49QLTDPAZcALQr5lw/tracks',
#     'total': 15},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7Fc3N49QLTDPAZcALQr5lw'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2yFTJoVBCrmrFB8pt9x0GG'},
#    'href': 'https://api.spotify.com/v1/playlists/2yFTJoVBCrmrFB8pt9x0GG',
#    'id': '2yFTJoVBCrmrFB8pt9x0GG',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b27316b145d0659570091ada3dc6ab67616d0000b273490997bc549d6ef6c3e948b5ab67616d0000b27361543030b457d35dba791fa7ab67616d0000b273c4fe54f010091dc19dc42df4',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b27316b145d0659570091ada3dc6ab67616d0000b273490997bc549d6ef6c3e948b5ab67616d0000b27361543030b457d35dba791fa7ab67616d0000b273c4fe54f010091dc19dc42df4',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b27316b145d0659570091ada3dc6ab67616d0000b273490997bc549d6ef6c3e948b5ab67616d0000b27361543030b457d35dba791fa7ab67616d0000b273c4fe54f010091dc19dc42df4',
#      'width': 60}],
#    'name': 'Power',
#    'owner': {'display_name': 'GWilson',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/9qwpnpaxd9zbx1q1jrdh9bxz1'},
#     'href': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'id': '9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'type': 'user',
#     'uri': 'spotify:user:9qwpnpaxd9zbx1q1jrdh9bxz1'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjMsOTI2NTA4MDkzMzk3ODliYzA1MmZiMDIyNjAxYzE2ZTdhOGZhNDM0Ng==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2yFTJoVBCrmrFB8pt9x0GG/tracks',
#     'total': 22},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2yFTJoVBCrmrFB8pt9x0GG'},
#   {'collaborative': False,
#    'description': 'The songs you loved most this year, all wrapped up.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1Ett3hCenVBBbT'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1Ett3hCenVBBbT',
#    'id': '37i9dQZF1Ett3hCenVBBbT',
#    'images': [{'height': None,
#      'url': 'https://lineup-images.scdn.co/your-top-songs-2019_LARGE-en.jpg',
#      'width': None}],
#    'name': 'Your Top Songs 2019',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MjYyNjk3MjcsMDAwMDAwMDA2OTg2YTYxNzk5NGFkODUzZTUxYzUyYmMwMjU5NmI2YQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1Ett3hCenVBBbT/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1Ett3hCenVBBbT'},
#   {'collaborative': False,
#    'description': "When you've got ice water coursing through your veins, you need tracks that relate. Doesn't get any more real than this.",
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWYfVy6zzMSPv'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYfVy6zzMSPv',
#    'id': '37i9dQZF1DWYfVy6zzMSPv',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003051e731d598ea845c3c542ef',
#      'width': None}],
#    'name': 'Clinically Cold',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MTU2ODAxODg5NywwMDAwMDAwNTAwMDAwMTVkYzcxMzAyNTcwMDAwMDE2ZDE1MzU5YjZk',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWYfVy6zzMSPv/tracks',
#     'total': 57},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DWYfVy6zzMSPv'},
#   {'collaborative': False,
#    'description': 'Your weekly mixtape of fresh music. Enjoy new music and deep cuts picked for you. Updates every Monday.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQ
',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1EzAoQEzfoV9BVBG8YpT0B/tracks',
#     'total': 49},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1EzAoQEzfoV9BVBG8YpT0B'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4O3l7lSzibCMNHjFHRABv4'},
#    'href': 'https://api.spotify.com/v1/playlists/4O3l7lSzibCMNHjFHRABv4',
#    'id': '4O3l7lSzibCMNHjFHRABv4',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b273041996ab5980514b56241a05ab67616d0000b273660ee24281a547103f466ff5ab67616d0000b273af831c46ce689d37520c429fab67616d0000b273c0e7bf5cdd630f314f20586a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b273041996ab5980514b56241a05ab67616d0000b273660ee24281a547103f466ff5ab67616d0000b273af831c46ce689d37520c429fab67616d0000b273c0e7bf5cdd630f314f20586a',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b273041996ab5980514b56241a05ab67616d0000b273660ee24281a547103f466ff5ab67616d0000b273af831c46ce689d37520c429fab67616d0000b273c0e7bf5cdd630f314f20586a',
#      'width': 60}],
#    'name': '1x Season',
#    'owner': {'display_name': 'GWilson',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/9qwpnpaxd9zbx1q1jrdh9bxz1'},
#     'href': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'id': '9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'type': 'user',
#     'uri': 'spotify:user:9qwpnpaxd9zbx1q1jrdh9bxz1'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTksMDZlM2YxZWUyNjg0MjNiM2M0MmM1ZDIyNTBjNTVjZDNiYzU3YzRiMg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4O3l7lSzibCMNHjFHRABv4/tracks',
#     'total': 16},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4O3l7lSzibCMNHjFHRABv4'},
#   {'collaborative': False,
#    'description': 'Based off the songs listed from sangled&#x27;s post on Tumblr + the songs in the replies&#x2F;tags. No more updates being added due to no longer being active on Tumblr.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2aExPKjlJMvGKG5lo2PAi4'},
#    'href': 'https://api.spotify.com/v1/playlists/2aExPKjlJMvGKG5lo2PAi4',
#    'id': '2aExPKjlJMvGKG5lo2PAi4',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb91693b4eb20de07579d009b0',
#      'width': None}],
#    'name': 'looking back now our journey is over',
#    'owner': {'display_name': 'eldritchorchid',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/eldritchorchid'},
#     'href': 'https://api.spotify.com/v1/users/eldritchorchid',
#     'id': 'eldritchorchid',
#     'type': 'user',
#     'uri': 'spotify:user:eldritchorchid'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MjI4LDYyMjcwY2NiMDYxY2U4ZTU4MmRkNWNhMzQ3ZmMwNzQzMWJjZDE2ZDI=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2aExPKjlJMvGKG5lo2PAi4/tracks',
#     'total': 136},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2aExPKjlJMvGKG5lo2PAi4'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3dqaRKdvf8zYnMa4eYoJTi'},
#    'href': 'https://api.spotify.com/v1/playlists/3dqaRKdvf8zYnMa4eYoJTi',
#    'id': '3dqaRKdvf8zYnMa4eYoJTi',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733dfd61321992de4a3b8bf3bfab67616d0000b2739b87f413c6b36b076cb7d588ab67616d0000b273c0e7bf5cdd630f314f20586aab67616d0000b273f8f048a5f4749c970078a4fb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733dfd61321992de4a3b8bf3bfab67616d0000b2739b87f413c6b36b076cb7d588ab67616d0000b273c0e7bf5cdd630f314f20586aab67616d0000b273f8f048a5f4749c970078a4fb',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733dfd61321992de4a3b8bf3bfab67616d0000b2739b87f413c6b36b076cb7d588ab67616d0000b273c0e7bf5cdd630f314f20586aab67616d0000b273f8f048a5f4749c970078a4fb',
#      'width': 60}],
#    'name': 'Recommendations',
#    'owner': {'display_name': 'GWilson',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/9qwpnpaxd9zbx1q1jrdh9bxz1'},
#     'href': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'id': '9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'type': 'user',
#     'uri': 'spotify:user:9qwpnpaxd9zbx1q1jrdh9bxz1'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MixlNDg2YzNhZjhlNWFiZWRkNDhmNGMyM2Y5ODJjNzhiYTI1YzUwYzNi',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3dqaRKdvf8zYnMa4eYoJTi/tracks',
#     'total': 20},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:

#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b273a41d1dc77dfb374ed243e5a8ab67616d0000b273ab4da6c3f47506c90c5e56a3ab67616d0000b273b3359ec982cefac51683d574ab67616d0000b273e378ad289b695cfd773ca7b7',
#      'width': 60}],
#    'name': 'Grant Wilson Interview Playlist',
#    'owner': {'display_name': 'GWilson',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/9qwpnpaxd9zbx1q1jrdh9bxz1'},
#     'href': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'id': '9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'type': 'user',
#     'uri': 'spotify:user:9qwpnpaxd9zbx1q1jrdh9bxz1'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MixjYzMzZmU5MDc3N2JmOWE5NmRmMTY0MjhhMDlkZWM2NWZjMTk5NTQ2',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/12evQfKTcgtqjMfXcJnrwX/tracks',
#     'total': 20},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:12evQfKTcgtqjMfXcJnrwX'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2zODK4zQCrc57BSB2RnDsi'},
#    'href': 'https://api.spotify.com/v1/playlists/2zODK4zQCrc57BSB2RnDsi',
#    'id': '2zODK4zQCrc57BSB2RnDsi',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb4a3e9fff0ddd3b1e8894577e',
#      'width': None}],
#    'name': 'Erging Masterlist',
#    'owner': {'display_name': 'Marcel Bedard',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/galloog1'},
#     'href': 'https://api.spotify.com/v1/users/galloog1',
#     'id': 'galloog1',
#     'type': 'user',
#     'uri': 'spotify:user:galloog1'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MTA5Nyw5NGI4OTVjMThlYmMzZDE3M2VjYjgyMWYwMDc2ZTdkZGVkYjg2Yjkw',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2zODK4zQCrc57BSB2RnDsi/tracks',
#     'total': 1649},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2zODK4zQCrc57BSB2RnDsi'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/32qJljfKdE1VeWwOvsikT2'},
#    'href': 'https://api.spotify.com/v1/playlists/32qJljfKdE1VeWwOvsikT2',
#    'id': '32qJljfKdE1VeWwOvsikT2',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b273364bc70b069713b8818f7c7eab67616d0000b273420f4243a8b7d4923d461d41ab67616d0000b2736357eef63bcab4f5b551b216ab67616d0000b2737e4c30695aa3f09f32b01caf',
#      'width': 640},
#     {'height': 300,
# ...
#     'external_urls': {'spotify': 'https://open.spotify.com/user/9qwpnpaxd9zbx1q1jrdh9bxz1'},
#     'href': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'id': '9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'type': 'user',
#     'uri': 'spotify:user:9qwpnpaxd9zbx1q1jrdh9bxz1'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MjAsYjcwNWQxNWQzNDc5ZTlhM2ViOWFiY2I5NjQyMzg1MTA1MmVhNDA0MA==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4pbXDTiZzJJMvqGug2swsu/tracks',
#     'total': 19},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4pbXDTiZzJJMvqGug2swsu'},
#   {'collaborative': False,
#    'description': 'Because we all deserve great pop love songs in one playlist.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX50QitC6Oqtn'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX50QitC6Oqtn',
#    'id': '37i9dQZF1DX50QitC6Oqtn',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000003505e19aaff29a5dc3bc2503c',
#      'width': None}],
#    'name': 'Love Pop',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MTYyNTY4OTQxMSwwMDAwMDAwMGQ0MWQ4Y2Q5OGYwMGIyMDRlOTgwMDk5OGVjZjg0Mjdl',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX50QitC6Oqtn/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1DX50QitC6Oqtn'},
#   {'collaborative': False,
#    'description': 'The songs you loved most this year, all wrapped up.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EjtIGfbkswre5'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EjtIGfbkswre5',
#    'id': '37i9dQZF1EjtIGfbkswre5',
#    'images': [{'height': None,
#      'url': 'https://lineup-images.scdn.co/your-top-songs-2018_LARGE-en.jpg',
#      'width': None}],
#    'name': 'Your Top Songs 2018',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MjU3NjA4MjYsMDAwMDAwMDBlMTVkNThhZjVhNzRmZmJmYmI3ZTdjMmVlZDlhN2FkYQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EjtIGfbkswre5/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1EjtIGfbkswre5'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5lH1V4p8inZrjP8brSoIdm'},
#    'href': 'https://api.spotify.com/v1/playlists/5lH1V4p8inZrjP8brSoIdm',
#    'id': '5lH1V4p8inZrjP8brSoIdm',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730f6e34072354d1ec51e40e16ab67616d0000b2734b1899123e484c034e31164eab67616d0000b273597905f8f46dfc60f5a6d11fab67616d0000b273660aadbda2da6b1c2dd3d1a5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2
},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/6rw3blbpNJ7TLTxF85gKDK'},
#    'href': 'https://api.spotify.com/v1/playlists/6rw3blbpNJ7TLTxF85gKDK',
#    'id': '6rw3blbpNJ7TLTxF85gKDK',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2735767e044062c6d03256397e5ab67616d0000b273590f8e8f95cf45872e551652ab67616d0000b27390b9f4c171f58aea8d45af4dab67616d0000b2739a3c9eebbc9a748c0799bf21',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2735767e044062c6d03256397e5ab67616d0000b273590f8e8f95cf45872e551652ab67616d0000b27390b9f4c171f58aea8d45af4dab67616d0000b2739a3c9eebbc9a748c0799bf21',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b2735767e044062c6d03256397e5ab67616d0000b273590f8e8f95cf45872e551652ab67616d0000b27390b9f4c171f58aea8d45af4dab67616d0000b2739a3c9eebbc9a748c0799bf21',
#      'width': 60}],
#    'name': 'How Do You Like Me Now',
#    'owner': {'display_name': 'GWilson',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/9qwpnpaxd9zbx1q1jrdh9bxz1'},
#     'href': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'id': '9qwpnpaxd9zbx1q1jrdh9bxz1',
#     'type': 'user',
#     'uri': 'spotify:user:9qwpnpaxd9zbx1q1jrdh9bxz1'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTksODkwNzIyMWU3ZDM5YTZlZjgwYTAxYzQ2YTlmN2ZkNDFmZWZhNWExYg==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/6rw3blbpNJ7TLTxF85gKDK/tracks',
#     'total': 17},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:6rw3blbpNJ7TLTxF85gKDK'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3eigIjdeA6V0M4MKxCem56'},
#    'href': 'https://api.spotify.com/v1/playlists/3eigIjdeA6V0M4MKxCem56',
#    'id': '3eigIjdeA6V0M4MKxCem56',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730f7e15d4e0deac1411f43175ab67616d0000b273676f606479e6ca9c69f55caaab67616d0000b273bf0380fdf64ae46fd7b2e629ab67616d0000b273d31937244117e7bc6213ee8e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730f7e15d4e0deac1411f43175ab67616d0000b273676f606479e6ca9c69f55caaab67616d0000b273bf0380fdf64ae46fd7b2e629ab67616d0000b273d31937244117e7bc6213ee8e',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730f7e15d4e0deac1411f43175ab67616d0000b273676f606479e6ca9c69f55caaab67616d0000b273bf0380fdf64ae46fd7b2e629ab67616d0000b273d31937244117e7bc6213ee8e',
#      'width': 60}],
#    'name': 'Work',
#    'owner': {'display_name': 'jdub 🦦',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/jdub5538'},
#     'href': 'https://api.spotify.com/v1/users/jdub5538',
#     'id': 'jdub5538',
#     'type': 'user',
#     'uri': 'spotify:user:jdub5538'},
#    'primary_color': None,
#    'public': False,
#    'snapshot_id': 'MTksYjk2YzI4NmQxM2RmNjFmN2VkZDQxOWQzNDhlZjU3NmZhODIwYzZjZQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3eigIjdeA6V0M4MKxCem56/tracks',
#     'total': 15},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3eigIjdeA6V0M4MKxCem56'}],
#  'limit': 50,
#  'next': 'https://api.spotify.com/v1/users/9qwpnpaxd9zbx1q1jrdh9bxz1/playlists?offset=50&limit=50',
#  'offset': 0,
#  'previous': None,
#  'total': 70}

# %%
# Create New Playlist
playlist_details = session.user_playlist_create(user = '9qwpnpaxd9zbx1q1jrdh9bxz1',
                                                name = "Jams")

# Add Tracks to new playlist
session.user_playlist_add_tracks(user = '9qwpnpaxd9zbx1q1jrdh9bxz1',
                                 playlist_id = playlist_details["id"],
                                 tracks = rec_tracks)
# Out:
# {'snapshot_id': 'MTIsYmFmYTFiZDliMWMxMjkxZGZjZjMyZjA1ZTg0YTc4OWJjZGU3MThjOA=='}
